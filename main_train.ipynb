# %% [markdown]
# *This is the training part of the final model. Outputs are displayed in cells or as web links in markdown.*

# %% [markdown]
# #  Project in brief
# - **In this project, we try to train a ping pong player who learns the direction and distance of optimal movement through:**
#     + A six-layered Convolutional Neural Network to recognize ball behavior from updated screen input
#     + A reinforcement learning system which targets the learning agent at and against behaviors e.g. Catching the ball, avoiding loops
# - **Game rules:**
#     + The ball is served by the opponent AI first, at randomd angle; Upon wining, the serving right is passed to the opponent
#     + Score in testing (shown on pygame screen) is calculated as one additional points if opponent fails to catch the ball
# - **File structure** - Project.zip contains:
#     + A *pygame_player.py* for overall functions
#     + A *pong.py* for defining opponent AI and screen display configurations
#     + A *pong_player.py* for defining example class for playing pong which imports from pygame_player.py
#     + A *main_train.ipynb* for training the learning agent
#     + A *main_test.ipynb* for testing and demonstrating agent performance

# %% [markdown]
# # Our design
# - **Opponent player** - We designed the opponent pong player to be competent while vulnerable:
#     + Competent: In order for it to catch most balls, we make the opponent cheat by
#         - reading the ball's direction from coordinates
#         - aligning the ball's speed with its own speed
#     + Vulnerable:
#         - The opponent's action is defined at a random rate
#         - Due to limited speed, it cannot catch certain servings e.g. when the ball heads from upper half towards upper corner while it is in the lower half of the field
# - **RL process:**
#     + Observation VS exploring - We settled on 100k observations steps and 1000k exploring steps. To balance the exploration/exploitation tradeoff, we raised the observation steps after finding our agent trapped in a local optimal policy to only move downwards
#     + Learning reward - We designed the reward system to enhance several actions:
#         - For the first catch in a round, whichever player catches the ball is rewarded 3 points. We encourage our agent to catch more serve with this design
#         - For continuing catch in the round, reward is given at $3*0.6^{catch times}$. We discourage our agent to be trapped in tacit agreement to stay put and make every catch
# - **CNN network:**
#     + The structure is based on DeepMind
#     + We improved it with ReLu, adding one maxpooling layer for stability, and adding one dropout layer against overfitting

# %% [markdown]
# # Improvement
# 1. **Model 1 Baseline: **
#     - Features:
#         + Basic reward (1 point if opponent fail to catch)
#         + 2-directioned serve (ball starts from the middle line 45 degrees to one of the four corners)
#         + 3-layered basic
#         + 20k observation steps
#     - Performace (at 500k steps):
#     - Problems:
#         + Local optimal- the bar was easily trapped in a local policy of only moving downwards/upwards
#         + Not amazing performace - positive but slow linear learning rate
#     - Code: github
#
# 2. **Model 2:**
#     - Improvement: In terms of the above problems, we -
#         + increased the number of observation steps to 50000, and created checkpoints every 50000 steps to check how much performance has improved
#         + raised the difficulty of the game by serving the ball at random angle
#         + improved CNN to adopt DeepMind structure
#     - Performance (at 500k steps):
#     - Problems: New problems emerged -
#         + The two bars reached a “consensus” to stay in diagonal corners with which minimal movement ensures no one loses the game, this resulted in no update of the policy
#         + Still learning rate (We considered it to be the result of harder rules/stronger opponent thus fewer positive reward)
#     - Code:
#
# 3. **Model 3 Final version:**
#     - Improvement: In terms of the above problems, we -
#         + updated reward system to penalize repeated trajectory of the ball movement. Namely, reward will experience an exponential decay with a rate of 0.6 every time it hits the bar in a specific round, and the loop is forced to break after 10 hits
#         + upgraded CNN with RELU
#     - Performance (at 1000k steps): [Video performance](https://drive.google.com/open?id=1othJyEePWy1O4lo9Et4UJgV19X6oJd4Z)
#     - Code:

# %%
import os
os.environ['SDL_VIDEODRIVER']='dummy'
import random
from collections import deque
from pong_player import PongPlayer
import tensorflow as tf
import numpy as np
import cv2
from pygame.constants import K_DOWN, K_UP, K_RIGHT

# %%
class DeepQPongPlayer(PongPlayer):
    num_actions = 3  # Number of valid actions. In this case up, still and down
    discount_rate = 0.99  # Decay rate of past observations
    obs_steps = 100000.  # Time steps to observe before training
    exp_steps = 1000000.  # Frames over which to anneal epsilon
    alpha_init = 1.0  # Starting chance of an action being random
    alpha_final = 0.05  # Final chance of an action being random
    buffer_size = 150000  # Number of observations to remember
    mini_batch = 64  # Size of mini batches
    num_frames = 4  # Number of frames to store in the state
    resized_image_x, resized_image_y = (80, 80)
    last_ind, action_ind, reward_ind, current_ind, final_ind = range(5)
    record_interval = 49999
    learning_rate = 1e-6
    record_scores_len = 200.

    
    def __init__(self, checkpoint_path="deep_q_pong_networks_5", playback_mode=False, verbose_logging=False):
        """
        Example of deep q network for pong

        :param checkpoint_path: directory to store checkpoints in
        :type checkpoint_path: str
        :param playback_mode: if true games runs in real time mode and demos itself running
        :type playback_mode: bool
        :param verbose_logging: If true then extra log information is printed to std out
        :type verbose_logging: bool
        """
        self.reward_history = deque()
        self.reward_memory = 0
        
        self._playback_mode = playback_mode
        super(DeepQPongPlayer, self).__init__(force_game_fps=8, run_real_time=playback_mode)
        self.verbose_logging = verbose_logging
        self._checkpoint_path = checkpoint_path
        
        with tf.device('/gpu:0'):

            self._session = tf.Session()
            self._input_layer, self._output_layer = DeepQPongPlayer._create_network()

            self._action = tf.placeholder("float", [None, self.num_actions])
            self._target = tf.placeholder("float", [None])

            readout_action = tf.reduce_sum(tf.multiply(self._output_layer, self._action), reduction_indices=1)

            cost = tf.reduce_mean(tf.square(self._target - readout_action))
            self._train_operation = tf.train.RMSPropOptimizer(self.learning_rate).minimize(cost)

        self._observations = deque()
        self._last_scores = deque()

        # Initialize first action to do nothing
        self._last_action = np.zeros(self.num_actions)
        self._last_action[1] = 1

        self._last_state = None
        self._probability_of_random_action = self.alpha_init
        self._time = 0

        self._session.run(tf.global_variables_initializer())
        
        # Load checkpoints
        if not os.path.exists(self._checkpoint_path):
            os.mkdir(self._checkpoint_path)
        
        self._saver = tf.train.Saver()
        checkpoint = tf.train.get_checkpoint_state(self._checkpoint_path)

        if checkpoint and checkpoint.model_checkpoint_path:
            self._saver.restore(self._session, checkpoint.model_checkpoint_path)
            print("Loaded checkpoints %s" % checkpoint.model_checkpoint_path)
        elif playback_mode:
            raise Exception("Could not load checkpoints for playback")
     
            
    def get_keys_pressed(self, screen_array, reward, terminal):
        # scale down screen image
        screen_resized_grayscaled = cv2.cvtColor(cv2.resize(screen_array,
                                                            (self.resized_image_x, self.resized_image_y)),
                                                 cv2.COLOR_BGR2GRAY)
        # set the pixels to all be 0. or 1.
        _, screen_resized_binary = cv2.threshold(screen_resized_grayscaled, 1, 255, cv2.THRESH_BINARY)

        # update scores
        if reward != 0.0:
            self._last_scores.append(reward)
            if len(self._last_scores) > self.record_scores_len:
                self._last_scores.popleft()
        
        # update screen input 
        if self._last_state is None:
            # the _last_state will contain the image data from the last self.num_frames frames
            self._last_state = np.stack(tuple(screen_resized_binary for _ in range(self.num_frames)), axis=2)
            return DeepQPongPlayer._key_presses_from_action(self._last_action)

        screen_resized_binary = np.reshape(screen_resized_binary,
                                               (self.resized_image_x, self.resized_image_y, 1))       
        current_state = np.append(self._last_state[:, :, 1:], screen_resized_binary, axis=2)

        if not self._playback_mode:
            # store the transition in previous_observations
            self._observations.append((self._last_state, self._last_action, reward, current_state, terminal))

            if len(self._observations) > self.buffer_size:
                self._observations.popleft()

            # only train if done observing
            if len(self._observations) > self.obs_steps:
                self._train()
                self._time += 1
            elif ((len(self._observations)+1) % 1000 == 0):
                print('Observation -', len(self._observations)+1,'/',int(self.obs_steps))

        # update the old values
        self._last_state = current_state
        self._last_action = self._choose_next_action()

        if not self._playback_mode:
            # gradually reduce the probability of a random actionself
            if self._probability_of_random_action > self.alpha_final \
                    and len(self._observations) > self.obs_steps:
                self._probability_of_random_action -= \
                    (self.alpha_init - self.alpha_final) / self.exp_steps

            self.reward_memory += reward
            if (self._time > 1000 and self._time % 1000 == 0):
                self.reward_history.append(self.reward_memory / 1000)
                self.reward_memory = 0
                print("Training - Time: %s; Reward: %s" % (self._time, round(self.reward_history[-1],4)))

            if (self._time >= self.exp_steps-1):
                return [K_RIGHT]
            else:
                return DeepQPongPlayer._key_presses_from_action(self._last_action)

    def _choose_next_action(self):
        new_action = np.zeros([self.num_actions])

        if (not self._playback_mode) and (random.random() <= self._probability_of_random_action):
            # choose an action randomly
            action_index = random.randrange(self.num_actions)
        else:
            # choose an action given our last state
            readout_t = self._session.run(self._output_layer, feed_dict={self._input_layer: [self._last_state]})[0]
            if self.verbose_logging:
                print("Action Q-Values are %s" % readout_t)
            action_index = np.argmax(readout_t)

        new_action[action_index] = 1
        return new_action # 

    def _train(self):
        # sample a mini_batch to train on
        mini_batch = random.sample(self._observations, self.mini_batch)
        # get the batch variables
        previous_states = [d[self.last_ind] for d in mini_batch]
        actions = [d[self.action_ind] for d in mini_batch]
        rewards = [d[self.reward_ind] for d in mini_batch]
        current_states = [d[self.current_ind] for d in mini_batch]
        agents_expected_reward = []
        # this gives us the agents expected reward for each action we might
        agents_reward_per_action = self._session.run(self._output_layer, feed_dict={self._input_layer: current_states})
        for i in range(len(mini_batch)):
            if mini_batch[i][self.final_ind]:
                # this was a terminal frame so there is no future reward...
                agents_expected_reward.append(rewards[i])
            else:
                agents_expected_reward.append(
                    rewards[i] + self.discount_rate * np.max(agents_reward_per_action[i]))

        # learn that these actions in these states lead to this reward
        self._session.run(self._train_operation, feed_dict={
            self._input_layer: previous_states,
            self._action: actions,
            self._target: agents_expected_reward})

        # save checkpoints for later
        if self._time % self.record_interval == 0:
            self._saver.save(self._session, self._checkpoint_path + '/network', global_step=self._time)

    def _create_network():
        # network weights
        with tf.device('/gpu:0'):

        #if 1:
            input_layer = tf.placeholder("float", [None, DeepQPongPlayer.resized_image_x, DeepQPongPlayer.resized_image_y,
                                               DeepQPongPlayer.num_frames])   # Input layer
            
            
            w_1 = tf.Variable(tf.truncated_normal([8, 8, DeepQPongPlayer.num_frames, 16], stddev=0.01))
            b_1 = tf.Variable(tf.constant(0.01, shape=[16]))
            layer_conv1 = tf.nn.relu(tf.nn.conv2d(input_layer, w_1, strides=[1, 4, 4, 1], padding="SAME") + b_1,
                                name= 'Conv1')
            layer_pool1 = tf.nn.max_pool(layer_conv1, ksize=[1, 2, 2, 1],
                                                    strides=[1, 2, 2, 1], padding="SAME")

            #FIRST HIDDEN LAYER: CONV LAYER, SHAPE =(?, 10, 10, 16)
            # Note:
            # The paper of Deep Mind didn't specify a specific form of recifier nonlinearity. Here we use ReLU, 
            # which is often useful in computer vision topics. 
             
            w_2 = tf.Variable(tf.truncated_normal([4, 4, 16, 32], stddev=0.01))
            b_2 = tf.Variable(tf.constant(0.01, shape=[32]))            
            layer_conv2 = tf.nn.relu(tf.nn.conv2d(layer_pool1, w_2, strides=[1, 2, 2, 1], padding="SAME") + b_2,
                                name = 'Conv2')            
            # SECOND HIDDEN LAYER: CONV LAYER, SHAPE =(?, 5, 5, 32)
            
            layer_2_flat = tf.reshape(layer_conv2, [-1, 5 *5 * 32])
            layer_dense = tf.layers.dense(inputs=layer_2_flat, units=256,  activation=tf.nn.relu) 
            # THIRD HIDDEN LAYER: FULLY-CONNECTED(DENSE) LAYER, SHAPE = (?, 256)
            
            dropout = tf.layers.dropout(layer_dense, rate=0.2, name = 'Dropout_layer')
            # REGULARIZATION LAYER: TO AVOID OVERFITTING, SHAPE = (?, 256)
            
            output_layer = tf.layers.dense(inputs=dropout, units=3) 
            # OUTPUT LAYER

        return input_layer, output_layer 

    def _key_presses_from_action(action_set):
        if action_set[0] == 1:
            return [K_DOWN]
        elif action_set[1] == 1:
            return []
        elif action_set[2] == 1:
            return [K_UP]
        raise Exception("Unexpected action")

# %%
# print reward 
player2 = DeepQPongPlayer(checkpoint_path="advanced_model_60")
player2.start()
# Out:
# Observation - 1000 / 100000
# Observation - 2000 / 100000
# Observation - 3000 / 100000
# Observation - 4000 / 100000
# Observation - 5000 / 100000
# Observation - 6000 / 100000
# Observation - 7000 / 100000
# Observation - 8000 / 100000
# Observation - 9000 / 100000
# Observation - 10000 / 100000
# Observation - 11000 / 100000
# Observation - 12000 / 100000
# Observation - 13000 / 100000
# Observation - 14000 / 100000
# Observation - 15000 / 100000
# Observation - 16000 / 100000
# Observation - 17000 / 100000
# Observation - 18000 / 100000
# Observation - 19000 / 100000
# Observation - 20000 / 100000
# Observation - 21000 / 100000
# Observation - 22000 / 100000
# Observation - 23000 / 100000
# Observation - 24000 / 100000
# Observation - 25000 / 100000
# Observation - 26000 / 100000
# Observation - 27000 / 100000
# Observation - 28000 / 100000
# Observation - 29000 / 100000
# Observation - 30000 / 100000
# Observation - 31000 / 100000
# Observation - 32000 / 100000
# Observation - 33000 / 100000
# Observation - 34000 / 100000
# Observation - 35000 / 100000
# Observation - 36000 / 100000
# Observation - 37000 / 100000
# Observation - 38000 / 100000
# Observation - 39000 / 100000
# Observation - 40000 / 100000
# Observation - 41000 / 100000
# Observation - 42000 / 100000
# Observation - 43000 / 100000
# Observation - 44000 / 100000
# Observation - 45000 / 100000
# Observation - 46000 / 100000
# Observation - 47000 / 100000
# Observation - 48000 / 100000
# Observation - 49000 / 100000
# Observation - 50000 / 100000
# Observation - 51000 / 100000
# Observation - 52000 / 100000
# Observation - 53000 / 100000
# Observation - 54000 / 100000
# Observation - 55000 / 100000
# Observation - 56000 / 100000
# Observation - 57000 / 100000
# Observation - 58000 / 100000
# Observation - 59000 / 100000
# Observation - 60000 / 100000
# Observation - 61000 / 100000
# Observation - 62000 / 100000
# Observation - 63000 / 100000
# Observation - 64000 / 100000
# Observation - 65000 / 100000
# Observation - 66000 / 100000
# Observation - 67000 / 100000
# Observation - 68000 / 100000
# Observation - 69000 / 100000
# Observation - 70000 / 100000
# Observation - 71000 / 100000
# Observation - 72000 / 100000
# Observation - 73000 / 100000
# Observation - 74000 / 100000
# Observation - 75000 / 100000
# Observation - 76000 / 100000
# Observation - 77000 / 100000
# Observation - 78000 / 100000
# Observation - 79000 / 100000
# Observation - 80000 / 100000
# Observation - 81000 / 100000
# Observation - 82000 / 100000
# Observation - 83000 / 100000
# Observation - 84000 / 100000
# Observation - 85000 / 100000
# Observation - 86000 / 100000
# Observation - 87000 / 100000
# Observation - 88000 / 100000
# Observation - 89000 / 100000
# Observation - 90000 / 100000
# Observation - 91000 / 100000
# Observation - 92000 / 100000
# Observation - 93000 / 100000
# Observation - 94000 / 100000
# Observation - 95000 / 100000
# Observation - 96000 / 100000
# Observation - 97000 / 100000
# Observation - 98000 / 100000
# Observation - 99000 / 100000
# Observation - 100000 / 100000
# Training - Time: 2000; Reward: -15.5701
# Training - Time: 3000; Reward: -0.0996
# Training - Time: 4000; Reward: -0.1226
# Training - Time: 5000; Reward: -0.18
# Training - Time: 6000; Reward: -0.138
# Training - Time: 7000; Reward: -0.1332
# Training - Time: 8000; Reward: -0.115
# Training - Time: 9000; Reward: -0.1416
# Training - Time: 10000; Reward: -0.135
# Training - Time: 11000; Reward: -0.1706
# Training - Time: 12000; Reward: -0.14
# Training - Time: 13000; Reward: -0.1502
# Training - Time: 14000; Reward: -0.219
# Training - Time: 15000; Reward: -0.1346
# Training - Time: 16000; Reward: -0.186
# Training - Time: 17000; Reward: -0.201
# Training - Time: 18000; Reward: -0.101
# Training - Time: 19000; Reward: -0.1292
# Training - Time: 20000; Reward: -0.165
# Training - Time: 21000; Reward: -0.096
# Training - Time: 22000; Reward: -0.116
# Training - Time: 23000; Reward: -0.136
# Training - Time: 24000; Reward: -0.1224
# Training - Time: 25000; Reward: -0.13
# Training - Time: 26000; Reward: -0.147
# Training - Time: 27000; Reward: -0.1384
# Training - Time: 28000; Reward: -0.156
# Training - Time: 29000; Reward: -0.09
# Training - Time: 30000; Reward: -0.1374
# Training - Time: 31000; Reward: -0.199
# Training - Time: 32000; Reward: -0.1704
# Training - Time: 33000; Reward: -0.0974
# Training - Time: 34000; Reward: -0.18
# Training - Time: 35000; Reward: -0.1196
# Training - Time: 36000; Reward: -0.171
# Training - Time: 37000; Reward: -0.1594
# Training - Time: 38000; Reward: -0.1616
# Training - Time: 39000; Reward: -0.1886
# Training - Time: 40000; Reward: -0.201
# Training - Time: 41000; Reward: -0.138
# Training - Time: 42000; Reward: -0.1008
# Training - Time: 43000; Reward: -0.174
# Training - Time: 44000; Reward: -0.165
# Training - Time: 45000; Reward: -0.1916
# Training - Time: 46000; Reward: -0.146
# Training - Time: 47000; Reward: -0.181
# Training - Time: 48000; Reward: -0.09
# Training - Time: 49000; Reward: -0.201
# Training - Time: 50000; Reward: -0.1354
# Training - Time: 51000; Reward: -0.186
# Training - Time: 52000; Reward: -0.1024
# Training - Time: 53000; Reward: -0.17
# Training - Time: 54000; Reward: -0.211
# Training - Time: 55000; Reward: -0.1436
# Training - Time: 56000; Reward: -0.1684
# Training - Time: 57000; Reward: -0.102
# Training - Time: 58000; Reward: -0.1714
# Training - Time: 59000; Reward: -0.147
# Training - Time: 60000; Reward: -0.141
# Training - Time: 61000; Reward: -0.1654
# Training - Time: 62000; Reward: -0.168
# Training - Time: 63000; Reward: -0.15
# Training - Time: 64000; Reward: -0.1024
# Training - Time: 65000; Reward: -0.1076
# Training - Time: 66000; Reward: -0.132
# Training - Time: 67000; Reward: -0.1136
# Training - Time: 68000; Reward: -0.1102
# Training - Time: 69000; Reward: -0.1894
# Training - Time: 70000; Reward: -0.1436
# Training - Time: 71000; Reward: -0.1374
# Training - Time: 72000; Reward: -0.117
# Training - Time: 73000; Reward: -0.0952
# Training - Time: 74000; Reward: -0.104
# Training - Time: 75000; Reward: -0.1654
# Training - Time: 76000; Reward: -0.207
# Training - Time: 77000; Reward: -0.057
# Training - Time: 78000; Reward: -0.166
# Training - Time: 79000; Reward: -0.117
# Training - Time: 80000; Reward: -0.1796
# Training - Time: 81000; Reward: -0.0954
# Training - Time: 82000; Reward: -0.175
# Training - Time: 83000; Reward: -0.093
# Training - Time: 84000; Reward: -0.1624
# Training - Time: 85000; Reward: -0.1316
# Training - Time: 86000; Reward: -0.1324
# Training - Time: 87000; Reward: -0.0656
# Training - Time: 88000; Reward: -0.1914
# Training - Time: 89000; Reward: -0.166
# Training - Time: 90000; Reward: -0.1568
# Training - Time: 91000; Reward: -0.159
# Training - Time: 92000; Reward: -0.12
# Training - Time: 93000; Reward: -0.171
# Training - Time: 94000; Reward: -0.147
# Training - Time: 95000; Reward: -0.1556
# Training - Time: 96000; Reward: -0.188
# Training - Time: 97000; Reward: -0.192
# Training - Time: 98000; Reward: -0.1454
# Training - Time: 99000; Reward: -0.164
# Training - Time: 100000; Reward: -0.133
# Training - Time: 101000; Reward: -0.167
# Training - Time: 102000; Reward: -0.163
# Training - Time: 103000; Reward: -0.135
# Training - Time: 104000; Reward: -0.171
# Training - Time: 105000; Reward: -0.108
# Training - Time: 106000; Reward: -0.074
# Training - Time: 107000; Reward: -0.172
# Training - Time: 108000; Reward: -0.152
# Training - Time: 109000; Reward: -0.1232
# Training - Time: 110000; Reward: -0.1508
# Training - Time: 111000; Reward: -0.1584
# Training - Time: 112000; Reward: -0.168
# Training - Time: 113000; Reward: -0.1294
# Training - Time: 114000; Reward: -0.156
# Training - Time: 115000; Reward: -0.141
# Training - Time: 116000; Reward: -0.143
# Training - Time: 117000; Reward: -0.1114
# Training - Time: 118000; Reward: -0.1054
# Training - Time: 119000; Reward: -0.192
# Training - Time: 120000; Reward: -0.1046
# Training - Time: 121000; Reward: -0.1372
# Training - Time: 122000; Reward: -0.192
# Training - Time: 123000; Reward: -0.141
# Training - Time: 124000; Reward: -0.143
# Training - Time: 125000; Reward: -0.1274
# Training - Time: 126000; Reward: -0.1834
# Training - Time: 127000; Reward: -0.132
# Training - Time: 128000; Reward: -0.135
# Training - Time: 129000; Reward: -0.207
# Training - Time: 130000; Reward: -0.161
# Training - Time: 131000; Reward: -0.106
# Training - Time: 132000; Reward: -0.18
# Training - Time: 133000; Reward: -0.176
# Training - Time: 134000; Reward: -0.091
# Training - Time: 135000; Reward: -0.141
# Training - Time: 136000; Reward: -0.2
# Training - Time: 137000; Reward: -0.199
# Training - Time: 138000; Reward: -0.176
# Training - Time: 139000; Reward: -0.1476
# Training - Time: 140000; Reward: -0.147
# Training - Time: 141000; Reward: -0.1246
# Training - Time: 142000; Reward: -0.12
# Training - Time: 143000; Reward: -0.103
# Training - Time: 144000; Reward: -0.198
# Training - Time: 145000; Reward: -0.1136
# Training - Time: 146000; Reward: -0.171
# Training - Time: 147000; Reward: -0.162
# Training - Time: 148000; Reward: -0.1538
# Training - Time: 149000; Reward: -0.156
# Training - Time: 150000; Reward: -0.114
# Training - Time: 151000; Reward: -0.1764
# Training - Time: 152000; Reward: -0.153
# Training - Time: 153000; Reward: -0.1506
# Training - Time: 154000; Reward: -0.1216
# Training - Time: 155000; Reward: -0.0974
# Training - Time: 156000; Reward: -0.102
# Training - Time: 157000; Reward: -0.183
# Training - Time: 158000; Reward: -0.1136
# Training - Time: 159000; Reward: -0.144
# Training - Time: 160000; Reward: -0.1256
# Training - Time: 161000; Reward: -0.153
# Training - Time: 162000; Reward: -0.1254
# Training - Time: 163000; Reward: -0.171
# Training - Time: 164000; Reward: -0.1084
# Training - Time: 165000; Reward: -0.125
# Training - Time: 166000; Reward: -0.1566
# Training - Time: 167000; Reward: -0.123
# Training - Time: 168000; Reward: -0.1132
# Training - Time: 169000; Reward: -0.122
# Training - Time: 170000; Reward: -0.199
# Training - Time: 171000; Reward: -0.1534
# Training - Time: 172000; Reward: -0.141
# Training - Time: 173000; Reward: -0.213
# Training - Time: 174000; Reward: -0.1222
# Training - Time: 175000; Reward: -0.144
# Training - Time: 176000; Reward: -0.077
# Training - Time: 177000; Reward: -0.1006
# Training - Time: 178000; Reward: -0.1334
# Training - Time: 179000; Reward: -0.1376
# Training - Time: 180000; Reward: -0.0986
# Training - Time: 181000; Reward: -0.1388
# Training - Time: 182000; Reward: -0.144
# Training - Time: 183000; Reward: -0.14
# Training - Time: 184000; Reward: -0.1386
# Training - Time: 185000; Reward: -0.1076
# Training - Time: 186000; Reward: -0.1706
# Training - Time: 187000; Reward: -0.081
# Training - Time: 188000; Reward: -0.177
# Training - Time: 189000; Reward: -0.0986
# Training - Time: 190000; Reward: -0.144
# Training - Time: 191000; Reward: -0.168
# Training - Time: 192000; Reward: -0.137
# Training - Time: 193000; Reward: -0.112
# Training - Time: 194000; Reward: -0.171
# Training - Time: 195000; Reward: -0.149
# Training - Time: 196000; Reward: -0.1046
# Training - Time: 197000; Reward: -0.118
# Training - Time: 198000; Reward: -0.165
# Training - Time: 199000; Reward: -0.116
# Training - Time: 200000; Reward: -0.112
# Training - Time: 201000; Reward: -0.177
# Training - Time: 202000; Reward: -0.1324
# Training - Time: 203000; Reward: -0.111
# Training - Time: 204000; Reward: -0.171
# Training - Time: 205000; Reward: -0.15
# Training - Time: 206000; Reward: -0.1126
# Training - Time: 207000; Reward: -0.075
# Training - Time: 208000; Reward: -0.196
# Training - Time: 209000; Reward: -0.1444
# Training - Time: 210000; Reward: -0.153
# Training - Time: 211000; Reward: -0.1644
# Training - Time: 212000; Reward: -0.1456
# Training - Time: 213000; Reward: -0.1034
# Training - Time: 214000; Reward: -0.126
# Training - Time: 215000; Reward: -0.173
# Training - Time: 216000; Reward: -0.0914
# Training - Time: 217000; Reward: -0.15
# Training - Time: 218000; Reward: -0.1244
# Training - Time: 219000; Reward: -0.138
# Training - Time: 220000; Reward: -0.1314
# Training - Time: 221000; Reward: -0.148
# Training - Time: 222000; Reward: -0.0986
# Training - Time: 223000; Reward: -0.129
# Training - Time: 224000; Reward: -0.146
# Training - Time: 225000; Reward: -0.127
# Training - Time: 226000; Reward: -0.123
# Training - Time: 227000; Reward: -0.1614
# Training - Time: 228000; Reward: -0.199
# Training - Time: 229000; Reward: -0.1466
# Training - Time: 230000; Reward: -0.1136
# Training - Time: 231000; Reward: -0.075
# Training - Time: 232000; Reward: -0.096
# Training - Time: 233000; Reward: -0.1044
# Training - Time: 234000; Reward: -0.121
# Training - Time: 235000; Reward: -0.168
# Training - Time: 236000; Reward: -0.1556
# Training - Time: 237000; Reward: -0.12
# Training - Time: 238000; Reward: -0.162
# Training - Time: 239000; Reward: -0.143
# Training - Time: 240000; Reward: -0.133
# Training - Time: 241000; Reward: -0.171
# Training - Time: 242000; Reward: -0.1196
# Training - Time: 243000; Reward: -0.171
# Training - Time: 244000; Reward: -0.156
# Training - Time: 245000; Reward: -0.0836
# Training - Time: 246000; Reward: -0.135
# Training - Time: 247000; Reward: -0.164
# Training - Time: 248000; Reward: -0.135
# Training - Time: 249000; Reward: -0.1294
# Training - Time: 250000; Reward: -0.1136
# Training - Time: 251000; Reward: -0.132
# Training - Time: 252000; Reward: -0.1634
# Training - Time: 253000; Reward: -0.192
# Training - Time: 254000; Reward: -0.204
# Training - Time: 255000; Reward: -0.183
# Training - Time: 256000; Reward: -0.147
# Training - Time: 257000; Reward: -0.152
# Training - Time: 258000; Reward: -0.16
# Training - Time: 259000; Reward: -0.111
# Training - Time: 260000; Reward: -0.084
# Training - Time: 261000; Reward: -0.138
# Training - Time: 262000; Reward: -0.1624
# Training - Time: 263000; Reward: -0.195
# Training - Time: 264000; Reward: -0.171
# Training - Time: 265000; Reward: -0.113
# Training - Time: 266000; Reward: -0.1064
# Training - Time: 267000; Reward: -0.0966
# Training - Time: 268000; Reward: -0.095
# Training - Time: 269000; Reward: -0.108
# Training - Time: 270000; Reward: -0.0872
# Training - Time: 271000; Reward: -0.123
# Training - Time: 272000; Reward: -0.191
# Training - Time: 273000; Reward: -0.118
# Training - Time: 274000; Reward: -0.111
# Training - Time: 275000; Reward: -0.204
# Training - Time: 276000; Reward: -0.123
# Training - Time: 277000; Reward: -0.1016
# Training - Time: 278000; Reward: -0.156
# Training - Time: 279000; Reward: -0.201
# Training - Time: 280000; Reward: -0.141
# Training - Time: 281000; Reward: -0.0922
# Training - Time: 282000; Reward: -0.1704
# Training - Time: 283000; Reward: -0.1412
# Training - Time: 284000; Reward: -0.102
# Training - Time: 285000; Reward: -0.0986
# Training - Time: 286000; Reward: -0.116
# Training - Time: 287000; Reward: -0.1214
# Training - Time: 288000; Reward: -0.12
# Training - Time: 289000; Reward: -0.141
# Training - Time: 290000; Reward: -0.102
# Training - Time: 291000; Reward: -0.096
# Training - Time: 292000; Reward: -0.234
# Training - Time: 293000; Reward: -0.1404
# Training - Time: 294000; Reward: -0.189
# Training - Time: 295000; Reward: -0.189
# Training - Time: 296000; Reward: -0.1016
# Training - Time: 297000; Reward: -0.105
# Training - Time: 298000; Reward: -0.129
# Training - Time: 299000; Reward: -0.135
# Training - Time: 300000; Reward: -0.1586
# Training - Time: 301000; Reward: -0.156
# Training - Time: 302000; Reward: -0.147
# Training - Time: 303000; Reward: -0.138
# Training - Time: 304000; Reward: -0.159
# Training - Time: 305000; Reward: -0.098
# Training - Time: 306000; Reward: -0.1356
# Training - Time: 307000; Reward: -0.192
# Training - Time: 308000; Reward: -0.1156
# Training - Time: 309000; Reward: -0.16
# Training - Time: 310000; Reward: -0.147
# Training - Time: 311000; Reward: -0.099
# Training - Time: 312000; Reward: -0.117
# Training - Time: 313000; Reward: -0.072
# Training - Time: 314000; Reward: -0.11
# Training - Time: 315000; Reward: -0.109
# Training - Time: 316000; Reward: -0.15
# Training - Time: 317000; Reward: -0.156
# Training - Time: 318000; Reward: -0.0814
# Training - Time: 319000; Reward: -0.146
# Training - Time: 320000; Reward: -0.0816
# Training - Time: 321000; Reward: -0.1372
# Training - Time: 322000; Reward: -0.0896
# Training - Time: 323000; Reward: -0.1192
# Training - Time: 324000; Reward: -0.1024
# Training - Time: 325000; Reward: -0.1594
# Training - Time: 326000; Reward: -0.102
# Training - Time: 327000; Reward: -0.078
# Training - Time: 328000; Reward: -0.1226
# Training - Time: 329000; Reward: -0.161
# Training - Time: 330000; Reward: -0.1304
# Training - Time: 331000; Reward: -0.111
# Training - Time: 332000; Reward: -0.081
# Training - Time: 333000; Reward: -0.1164
# Training - Time: 334000; Reward: -0.1506
# Training - Time: 335000; Reward: -0.179
# Training - Time: 336000; Reward: -0.064
# Training - Time: 337000; Reward: -0.1046
# Training - Time: 338000; Reward: -0.108
# Training - Time: 339000; Reward: -0.122
# Training - Time: 340000; Reward: -0.134
# Training - Time: 341000; Reward: -0.076
# Training - Time: 342000; Reward: -0.099
# Training - Time: 343000; Reward: -0.189
# Training - Time: 344000; Reward: -0.1316
# Training - Time: 345000; Reward: -0.0934
# Training - Time: 346000; Reward: -0.156
# Training - Time: 347000; Reward: -0.1286
# Training - Time: 348000; Reward: -0.1054
# Training - Time: 349000; Reward: -0.1294
# Training - Time: 350000; Reward: -0.102
# Training - Time: 351000; Reward: -0.149
# Training - Time: 352000; Reward: -0.147
# Training - Time: 353000; Reward: -0.082
# Training - Time: 354000; Reward: -0.174
# Training - Time: 355000; Reward: -0.0804
# Training - Time: 356000; Reward: -0.1084
# Training - Time: 357000; Reward: -0.1084
# Training - Time: 358000; Reward: -0.0476
# Training - Time: 359000; Reward: -0.1114
# Training - Time: 360000; Reward: -0.1196
# Training - Time: 361000; Reward: -0.072
# Training - Time: 362000; Reward: -0.137
# Training - Time: 363000; Reward: -0.138
# Training - Time: 364000; Reward: -0.1146
# Training - Time: 365000; Reward: -0.0994
# Training - Time: 366000; Reward: -0.105
# Training - Time: 367000; Reward: -0.149
# Training - Time: 368000; Reward: -0.1334
# Training - Time: 369000; Reward: -0.138
# Training - Time: 370000; Reward: -0.0986
# Training - Time: 371000; Reward: -0.0956
# Training - Time: 372000; Reward: -0.132
# Training - Time: 373000; Reward: -0.113
# Training - Time: 374000; Reward: -0.16
# Training - Time: 375000; Reward: -0.141
# Training - Time: 376000; Reward: -0.147
# Training - Time: 377000; Reward: -0.072
# Training - Time: 378000; Reward: -0.0506
# Training - Time: 379000; Reward: -0.1264
# Training - Time: 380000; Reward: -0.086
# Training - Time: 381000; Reward: -0.078
# Training - Time: 382000; Reward: -0.0556
# Training - Time: 383000; Reward: -0.0668
# Training - Time: 384000; Reward: -0.159
# Training - Time: 385000; Reward: -0.1354
# Training - Time: 386000; Reward: -0.138
# Training - Time: 387000; Reward: -0.152
# Training - Time: 388000; Reward: -0.099
# Training - Time: 389000; Reward: -0.055
# Training - Time: 390000; Reward: -0.1466
# Training - Time: 391000; Reward: -0.1084
# Training - Time: 392000; Reward: -0.1106
# Training - Time: 393000; Reward: -0.12
# Training - Time: 394000; Reward: -0.1104
# Training - Time: 395000; Reward: -0.075
# Training - Time: 396000; Reward: -0.1174
# Training - Time: 397000; Reward: -0.0506
# Training - Time: 398000; Reward: -0.1134
# Training - Time: 399000; Reward: -0.081
# Training - Time: 400000; Reward: -0.0904
# Training - Time: 401000; Reward: -0.0614
# Training - Time: 402000; Reward: -0.1334
# Training - Time: 403000; Reward: -0.129
# Training - Time: 404000; Reward: -0.111
# Training - Time: 405000; Reward: -0.0487
# Training - Time: 406000; Reward: -0.072
# Training - Time: 407000; Reward: -0.068
# Training - Time: 408000; Reward: -0.0524
# Training - Time: 409000; Reward: -0.1384
# Training - Time: 410000; Reward: -0.033
# Training - Time: 411000; Reward: -0.0932
# Training - Time: 412000; Reward: -0.1204
# Training - Time: 413000; Reward: -0.129
# Training - Time: 414000; Reward: -0.102
# Training - Time: 415000; Reward: -0.1618
# Training - Time: 416000; Reward: -0.123
# Training - Time: 417000; Reward: -0.114
# Training - Time: 418000; Reward: -0.1124
# Training - Time: 419000; Reward: -0.069
# Training - Time: 420000; Reward: -0.072
# Training - Time: 421000; Reward: -0.129
# Training - Time: 422000; Reward: -0.125
# Training - Time: 423000; Reward: -0.099
# Training - Time: 424000; Reward: -0.111
# Training - Time: 425000; Reward: -0.1112
# Training - Time: 426000; Reward: -0.0842
# Training - Time: 427000; Reward: -0.126
# Training - Time: 428000; Reward: -0.063
# Training - Time: 429000; Reward: -0.1114
# Training - Time: 430000; Reward: -0.078
# Training - Time: 431000; Reward: -0.0716
# Training - Time: 432000; Reward: -0.0974
# Training - Time: 433000; Reward: -0.1264
# Training - Time: 434000; Reward: -0.117
# Training - Time: 435000; Reward: -0.107
# Training - Time: 436000; Reward: -0.1574
# Training - Time: 437000; Reward: -0.0586
# Training - Time: 438000; Reward: -0.057
# Training - Time: 439000; Reward: -0.1206
# Training - Time: 440000; Reward: -0.083
# Training - Time: 441000; Reward: -0.103
# Training - Time: 442000; Reward: -0.0868
# Training - Time: 443000; Reward: -0.085
# Training - Time: 444000; Reward: -0.092
# Training - Time: 445000; Reward: -0.0742
# Training - Time: 446000; Reward: -0.1334
# Training - Time: 447000; Reward: -0.102
# Training - Time: 448000; Reward: -0.0664
# Training - Time: 449000; Reward: -0.104
# Training - Time: 450000; Reward: -0.1384
# Training - Time: 451000; Reward: -0.086
# Training - Time: 452000; Reward: -0.067
# Training - Time: 453000; Reward: -0.078
# Training - Time: 454000; Reward: -0.0686
# Training - Time: 455000; Reward: -0.128
# Training - Time: 456000; Reward: -0.0914
# Training - Time: 457000; Reward: -0.1216
# Training - Time: 458000; Reward: -0.0606
# Training - Time: 459000; Reward: -0.117
# Training - Time: 460000; Reward: -0.0964
# Training - Time: 461000; Reward: -0.1256
# Training - Time: 462000; Reward: -0.1106
# Training - Time: 463000; Reward: -0.0874
# Training - Time: 464000; Reward: -0.147
# Training - Time: 465000; Reward: -0.096
# Training - Time: 466000; Reward: -0.0669
# Training - Time: 467000; Reward: -0.084
# Training - Time: 468000; Reward: -0.1126
# Training - Time: 469000; Reward: -0.07
# Training - Time: 470000; Reward: -0.1216
# Training - Time: 471000; Reward: -0.103
# Training - Time: 472000; Reward: -0.0804
# Training - Time: 473000; Reward: -0.082
# Training - Time: 474000; Reward: -0.066
# Training - Time: 475000; Reward: -0.084
# Training - Time: 476000; Reward: -0.102
# Training - Time: 477000; Reward: -0.095
# Training - Time: 478000; Reward: -0.0598
# Training - Time: 479000; Reward: -0.0844
# Training - Time: 480000; Reward: -0.0654
# Training - Time: 481000; Reward: -0.118
# Training - Time: 482000; Reward: -0.0836
# Training - Time: 483000; Reward: -0.1016
# Training - Time: 484000; Reward: -0.089
# Training - Time: 485000; Reward: -0.105
# Training - Time: 486000; Reward: -0.077
# Training - Time: 487000; Reward: -0.0794
# Training - Time: 488000; Reward: -0.0684
# Training - Time: 489000; Reward: -0.1232
# Training - Time: 490000; Reward: -0.101
# Training - Time: 491000; Reward: -0.091
# Training - Time: 492000; Reward: -0.147
# Training - Time: 493000; Reward: -0.0776
# Training - Time: 494000; Reward: -0.131
# Training - Time: 495000; Reward: -0.0812
# Training - Time: 496000; Reward: -0.0984
# Training - Time: 497000; Reward: -0.0842
# Training - Time: 498000; Reward: -0.105
# Training - Time: 499000; Reward: -0.065
# Training - Time: 500000; Reward: -0.136
# Training - Time: 501000; Reward: -0.0272
# Training - Time: 502000; Reward: -0.114
# Training - Time: 503000; Reward: -0.1294
# Training - Time: 504000; Reward: -0.0956
# Training - Time: 505000; Reward: -0.071
# Training - Time: 506000; Reward: -0.0596
# Training - Time: 507000; Reward: -0.06
# Training - Time: 508000; Reward: -0.077
# Training - Time: 509000; Reward: -0.0412
# Training - Time: 510000; Reward: -0.076
# Training - Time: 511000; Reward: -0.089
# Training - Time: 512000; Reward: -0.0728
# Training - Time: 513000; Reward: -0.066
# Training - Time: 514000; Reward: -0.083
# Training - Time: 515000; Reward: -0.0864
# Training - Time: 516000; Reward: -0.0606
# Training - Time: 517000; Reward: -0.102
# Training - Time: 518000; Reward: -0.0894
# Training - Time: 519000; Reward: -0.105
# Training - Time: 520000; Reward: -0.1146
# Training - Time: 521000; Reward: -0.1114
# Training - Time: 522000; Reward: -0.1276
# Training - Time: 523000; Reward: -0.066
# Training - Time: 524000; Reward: -0.072
# Training - Time: 525000; Reward: -0.133
# Training - Time: 526000; Reward: -0.165
# Training - Time: 527000; Reward: -0.131
# Training - Time: 528000; Reward: -0.102
# Training - Time: 529000; Reward: -0.1054
# Training - Time: 530000; Reward: -0.0906
# Training - Time: 531000; Reward: -0.05
# Training - Time: 532000; Reward: -0.086
# Training - Time: 533000; Reward: -0.084
# Training - Time: 534000; Reward: -0.074
# Training - Time: 535000; Reward: -0.084
# Training - Time: 536000; Reward: -0.1084
# Training - Time: 537000; Reward: -0.069
# Training - Time: 538000; Reward: -0.08
# Training - Time: 539000; Reward: -0.072
# Training - Time: 540000; Reward: -0.064
# Training - Time: 541000; Reward: -0.1136
# Training - Time: 542000; Reward: -0.1036
# Training - Time: 543000; Reward: -0.0596
# Training - Time: 544000; Reward: -0.073
# Training - Time: 545000; Reward: -0.092
# Training - Time: 546000; Reward: -0.0914
# Training - Time: 547000; Reward: -0.1016
# Training - Time: 548000; Reward: -0.072
# Training - Time: 549000; Reward: -0.0754
# Training - Time: 550000; Reward: -0.1096
# Training - Time: 551000; Reward: -0.0692
# Training - Time: 552000; Reward: -0.1083
# Training - Time: 553000; Reward: -0.0698
# Training - Time: 554000; Reward: -0.0776
# Training - Time: 555000; Reward: -0.116
# Training - Time: 556000; Reward: -0.091
# Training - Time: 557000; Reward: -0.126
# Training - Time: 558000; Reward: -0.1196
# Training - Time: 559000; Reward: -0.0514
# Training - Time: 560000; Reward: -0.0806
# Training - Time: 561000; Reward: -0.027
# Training - Time: 562000; Reward: -0.012
# Training - Time: 563000; Reward: -0.066
# Training - Time: 564000; Reward: -0.0858
# Training - Time: 565000; Reward: -0.1376
# Training - Time: 566000; Reward: -0.075
# Training - Time: 567000; Reward: -0.0508
# Training - Time: 568000; Reward: -0.095
# Training - Time: 569000; Reward: -0.0994
# Training - Time: 570000; Reward: -0.038
# Training - Time: 571000; Reward: -0.093
# Training - Time: 572000; Reward: -0.0892
# Training - Time: 573000; Reward: -0.0495
# Training - Time: 574000; Reward: -0.091
# Training - Time: 575000; Reward: -0.0866
# Training - Time: 576000; Reward: -0.075
# Training - Time: 577000; Reward: -0.11
# Training - Time: 578000; Reward: -0.0332
# Training - Time: 579000; Reward: -0.111
# Training - Time: 580000; Reward: -0.1152
# Training - Time: 581000; Reward: -0.018
# Training - Time: 582000; Reward: -0.1204
# Training - Time: 583000; Reward: -0.0934
# Training - Time: 584000; Reward: -0.0846
# Training - Time: 585000; Reward: -0.0476
# Training - Time: 586000; Reward: -0.0684
# Training - Time: 587000; Reward: -0.0991
# Training - Time: 588000; Reward: -0.069
# Training - Time: 589000; Reward: -0.057
# Training - Time: 590000; Reward: -0.085
# Training - Time: 591000; Reward: -0.093
# Training - Time: 592000; Reward: -0.104
# Training - Time: 593000; Reward: -0.079
# Training - Time: 594000; Reward: -0.09
# Training - Time: 595000; Reward: -0.11
# Training - Time: 596000; Reward: -0.0786
# Training - Time: 597000; Reward: -0.0926
# Training - Time: 598000; Reward: -0.044
# Training - Time: 599000; Reward: -0.1202
# Training - Time: 600000; Reward: -0.081
# Training - Time: 601000; Reward: -0.1196
# Training - Time: 602000; Reward: -0.0598
# Training - Time: 603000; Reward: -0.138
# Training - Time: 604000; Reward: -0.0776
# Training - Time: 605000; Reward: -0.05
# Training - Time: 606000; Reward: -0.0566
# Training - Time: 607000; Reward: -0.0632
# Training - Time: 608000; Reward: -0.0544
# Training - Time: 609000; Reward: -0.0326
# Training - Time: 610000; Reward: -0.0294
# Training - Time: 611000; Reward: -0.053
# Training - Time: 612000; Reward: -0.079
# Training - Time: 613000; Reward: -0.0882
# Training - Time: 614000; Reward: -0.0184
# Training - Time: 615000; Reward: -0.0384
# Training - Time: 616000; Reward: -0.0558
# Training - Time: 617000; Reward: -0.0896
# Training - Time: 618000; Reward: -0.119
# Training - Time: 619000; Reward: -0.0576
# Training - Time: 620000; Reward: -0.0896
# Training - Time: 621000; Reward: -0.0784
# Training - Time: 622000; Reward: -0.0836
# Training - Time: 623000; Reward: -0.1316
# Training - Time: 624000; Reward: -0.077
# Training - Time: 625000; Reward: -0.0666
# Training - Time: 626000; Reward: -0.099
# Training - Time: 627000; Reward: -0.0446
# Training - Time: 628000; Reward: -0.0844
# Training - Time: 629000; Reward: -0.048
# Training - Time: 630000; Reward: -0.068
# Training - Time: 631000; Reward: -0.078
# Training - Time: 632000; Reward: -0.0276
# Training - Time: 633000; Reward: -0.0595
# Training - Time: 634000; Reward: -0.051
# Training - Time: 635000; Reward: -0.096
# Training - Time: 636000; Reward: -0.0836
# Training - Time: 637000; Reward: -0.1204
# Training - Time: 638000; Reward: -0.0504
# Training - Time: 639000; Reward: -0.126
# Training - Time: 640000; Reward: -0.0508
# Training - Time: 641000; Reward: -0.0346
# Training - Time: 642000; Reward: -0.0826
# Training - Time: 643000; Reward: -0.079
# Training - Time: 644000; Reward: -0.071
# Training - Time: 645000; Reward: -0.0536
# Training - Time: 646000; Reward: -0.0486
# Training - Time: 647000; Reward: -0.095
# Training - Time: 648000; Reward: -0.079
# Training - Time: 649000; Reward: -0.0784
# Training - Time: 650000; Reward: -0.1024
# Training - Time: 651000; Reward: -0.045
# Training - Time: 652000; Reward: -0.053
# Training - Time: 653000; Reward: -0.057
# Training - Time: 654000; Reward: -0.0666
# Training - Time: 655000; Reward: -0.054
# Training - Time: 656000; Reward: -0.0419
# Training - Time: 657000; Reward: -0.1
# Training - Time: 658000; Reward: -0.077
# Training - Time: 659000; Reward: -0.0754
# Training - Time: 660000; Reward: -0.066
# Training - Time: 661000; Reward: -0.051
# Training - Time: 662000; Reward: -0.0696
# Training - Time: 663000; Reward: -0.0608
# Training - Time: 664000; Reward: -0.074
# Training - Time: 665000; Reward: -0.096
# Training - Time: 666000; Reward: -0.0942
# Training - Time: 667000; Reward: -0.0454
# Training - Time: 668000; Reward: -0.116
# Training - Time: 669000; Reward: -0.0734
# Training - Time: 670000; Reward: 0.0296
# Training - Time: 671000; Reward: -0.0664
# Training - Time: 672000; Reward: -0.0658
# Training - Time: 673000; Reward: -0.0794
# Training - Time: 674000; Reward: -0.101
# Training - Time: 675000; Reward: -0.09
# Training - Time: 676000; Reward: -0.024
# Training - Time: 677000; Reward: -0.099
# Training - Time: 678000; Reward: -0.094
# Training - Time: 679000; Reward: -0.0926
# Training - Time: 680000; Reward: -0.0676
# Training - Time: 681000; Reward: -0.0606
# Training - Time: 682000; Reward: -0.099
# Training - Time: 683000; Reward: -0.1016
# Training - Time: 684000; Reward: -0.1
# Training - Time: 685000; Reward: -0.0904
# Training - Time: 686000; Reward: -0.0476
# Training - Time: 687000; Reward: -0.06
# Training - Time: 688000; Reward: -0.0514
# Training - Time: 689000; Reward: -0.07
# Training - Time: 690000; Reward: -0.0788
# Training - Time: 691000; Reward: -0.0288
# Training - Time: 692000; Reward: 0.0088
# Training - Time: 693000; Reward: -0.0636
# Training - Time: 694000; Reward: -0.0244
# Training - Time: 695000; Reward: -0.072
# Training - Time: 696000; Reward: -0.048
# Training - Time: 697000; Reward: -0.0582
# Training - Time: 698000; Reward: -0.084
# Training - Time: 699000; Reward: -0.0496
# Training - Time: 700000; Reward: -0.055
# Training - Time: 701000; Reward: -0.0916
# Training - Time: 702000; Reward: -0.064
# Training - Time: 703000; Reward: -0.041
# Training - Time: 704000; Reward: -0.0344
# Training - Time: 705000; Reward: -0.0694
# Training - Time: 706000; Reward: -0.06
# Training - Time: 707000; Reward: -0.0436
# Training - Time: 708000; Reward: -0.0434
# Training - Time: 709000; Reward: -0.0924
# Training - Time: 710000; Reward: -0.063
# Training - Time: 711000; Reward: -0.0496
# Training - Time: 712000; Reward: -0.097
# Training - Time: 713000; Reward: -0.0544
# Training - Time: 714000; Reward: -0.03
# Training - Time: 715000; Reward: -0.0592
# Training - Time: 716000; Reward: -0.0368
# Training - Time: 717000; Reward: -0.082
# Training - Time: 718000; Reward: -0.1296
# Training - Time: 719000; Reward: -0.045
# Training - Time: 720000; Reward: -0.0852
# Training - Time: 721000; Reward: -0.0404
# Training - Time: 722000; Reward: -0.0476
# Training - Time: 723000; Reward: -0.0424
# Training - Time: 724000; Reward: -0.0686
# Training - Time: 725000; Reward: -0.0462
# Training - Time: 726000; Reward: -0.0394
# Training - Time: 727000; Reward: -0.0754
# Training - Time: 728000; Reward: -0.092
# Training - Time: 729000; Reward: -0.0754
# Training - Time: 730000; Reward: -0.0546
# Training - Time: 731000; Reward: -0.0476
# Training - Time: 732000; Reward: -0.029
# Training - Time: 733000; Reward: -0.0546
# Training - Time: 734000; Reward: -0.008
# Training - Time: 735000; Reward: -0.049
# Training - Time: 736000; Reward: -0.03
# Training - Time: 737000; Reward: -0.0296
# Training - Time: 738000; Reward: -0.08
# Training - Time: 739000; Reward: -0.058
# Training - Time: 740000; Reward: -0.081
# Training - Time: 741000; Reward: -0.075
# Training - Time: 742000; Reward: -0.059
# Training - Time: 743000; Reward: -0.0506
# Training - Time: 744000; Reward: -0.094
# Training - Time: 745000; Reward: -0.027
# Training - Time: 746000; Reward: -0.107
# Training - Time: 747000; Reward: -0.106
# Training - Time: 748000; Reward: -0.063
# Training - Time: 749000; Reward: -0.0368
# Training - Time: 750000; Reward: 0.0074
# Training - Time: 751000; Reward: -0.045
# Training - Time: 752000; Reward: -0.034
# Training - Time: 753000; Reward: -0.047
# Training - Time: 754000; Reward: -0.082
# Training - Time: 755000; Reward: -0.0474
# Training - Time: 756000; Reward: -0.051
# Training - Time: 757000; Reward: -0.024
# Training - Time: 758000; Reward: -0.03
# Training - Time: 759000; Reward: -0.0474
# Training - Time: 760000; Reward: -0.0634
# Training - Time: 761000; Reward: -0.0362
# Training - Time: 762000; Reward: -0.0754
# Training - Time: 763000; Reward: -0.059
# Training - Time: 764000; Reward: -0.0094
# Training - Time: 765000; Reward: -0.0696
# Training - Time: 766000; Reward: -0.0444
# Training - Time: 767000; Reward: -0.064
# Training - Time: 768000; Reward: -0.0654
# Training - Time: 769000; Reward: 0.0034
# Training - Time: 770000; Reward: -0.0338
# Training - Time: 771000; Reward: -0.051
# Training - Time: 772000; Reward: -0.048
# Training - Time: 773000; Reward: -0.0506
# Training - Time: 774000; Reward: 0.0004
# Training - Time: 775000; Reward: -0.0538
# Training - Time: 776000; Reward: -0.051
# Training - Time: 777000; Reward: -0.0268
# Training - Time: 778000; Reward: -0.051
# Training - Time: 779000; Reward: -0.0662
# Training - Time: 780000; Reward: -0.0476
# Training - Time: 781000; Reward: -0.0476
# Training - Time: 782000; Reward: -0.0342
# Training - Time: 783000; Reward: -0.0584
# Training - Time: 784000; Reward: -0.023
# Training - Time: 785000; Reward: -0.0686
# Training - Time: 786000; Reward: -0.0452
# Training - Time: 787000; Reward: -0.0092
# Training - Time: 788000; Reward: 0.004
# Training - Time: 789000; Reward: -0.034
# Training - Time: 790000; Reward: -0.0444
# Training - Time: 791000; Reward: -0.055
# Training - Time: 792000; Reward: -0.036
# Training - Time: 793000; Reward: -0.0564
# Training - Time: 794000; Reward: -0.0276
# Training - Time: 795000; Reward: -0.0354
# Training - Time: 796000; Reward: -0.0686
# Training - Time: 797000; Reward: -0.052
# Training - Time: 798000; Reward: -0.0308
# Training - Time: 799000; Reward: -0.0636
# Training - Time: 800000; Reward: -0.059
# Training - Time: 801000; Reward: -0.0138
# Training - Time: 802000; Reward: -0.0422
# Training - Time: 803000; Reward: -0.022
# Training - Time: 804000; Reward: -0.0094
# Training - Time: 805000; Reward: -0.0186
# Training - Time: 806000; Reward: -0.0486
# Training - Time: 807000; Reward: -0.0442
# Training - Time: 808000; Reward: -0.0452
# Training - Time: 809000; Reward: -0.034
# Training - Time: 810000; Reward: -0.0652
# Training - Time: 811000; Reward: -0.0676
# Training - Time: 812000; Reward: -0.058
# Training - Time: 813000; Reward: -0.0382
# Training - Time: 814000; Reward: -0.045
# Training - Time: 815000; Reward: -0.0578
# Training - Time: 816000; Reward: 0.0242
# Training - Time: 817000; Reward: -0.046
# Training - Time: 818000; Reward: -0.0252
# Training - Time: 819000; Reward: -0.057
# Training - Time: 820000; Reward: -0.036
# Training - Time: 821000; Reward: 0.0134
# Training - Time: 822000; Reward: 0.0077
# Training - Time: 823000; Reward: -0.009
# Training - Time: 824000; Reward: -0.0424
# Training - Time: 825000; Reward: -0.043
# Training - Time: 826000; Reward: -0.0352
# Training - Time: 827000; Reward: -0.0496
# Training - Time: 828000; Reward: -0.0484
# Training - Time: 829000; Reward: -0.0456
# Training - Time: 830000; Reward: -0.044
# Training - Time: 831000; Reward: -0.0486
# Training - Time: 832000; Reward: -0.033
# Training - Time: 833000; Reward: -0.0514
# Training - Time: 834000; Reward: -0.0244
# Training - Time: 835000; Reward: -0.0316
# Training - Time: 836000; Reward: -0.0456
# Training - Time: 837000; Reward: -0.0025
# Training - Time: 838000; Reward: -0.0478
# Training - Time: 839000; Reward: -0.0156
# Training - Time: 840000; Reward: -0.0272
# Training - Time: 841000; Reward: -0.0316
# Training - Time: 842000; Reward: -0.034
# Training - Time: 843000; Reward: -0.0634
# Training - Time: 844000; Reward: -0.044
# Training - Time: 845000; Reward: -0.0456
# Training - Time: 846000; Reward: -0.0116
# Training - Time: 847000; Reward: -0.019
# Training - Time: 848000; Reward: 0.0044
# Training - Time: 849000; Reward: -0.0184
# Training - Time: 850000; Reward: -0.0272
# Training - Time: 851000; Reward: -0.054
# Training - Time: 852000; Reward: -0.0406
# Training - Time: 853000; Reward: -0.0884
# Training - Time: 854000; Reward: -0.0386
# Training - Time: 855000; Reward: -0.0468
# Training - Time: 856000; Reward: -0.064
# Training - Time: 857000; Reward: -0.039
# Training - Time: 858000; Reward: -0.0398
# Training - Time: 859000; Reward: -0.036
# Training - Time: 860000; Reward: -0.0216
# Training - Time: 861000; Reward: -0.0276
# Training - Time: 862000; Reward: -0.02
# Training - Time: 863000; Reward: -0.015
# Training - Time: 864000; Reward: -0.0176
# Training - Time: 865000; Reward: -0.0126
# Training - Time: 866000; Reward: -0.0448
# Training - Time: 867000; Reward: -0.006
# Training - Time: 868000; Reward: -0.0086
# Training - Time: 869000; Reward: 0.004
# Training - Time: 870000; Reward: -0.0726
# Training - Time: 871000; Reward: 0.0077
# Training - Time: 872000; Reward: -0.0136
# Training - Time: 873000; Reward: 0.0174
# Training - Time: 874000; Reward: -0.0382
# Training - Time: 875000; Reward: -0.0257
# Training - Time: 876000; Reward: -0.004
# Training - Time: 877000; Reward: -0.0332
# Training - Time: 878000; Reward: -0.0082
# Training - Time: 879000; Reward: -0.0216
# Training - Time: 880000; Reward: -0.0263
# Training - Time: 881000; Reward: -0.0222
# Training - Time: 882000; Reward: -0.0416
# Training - Time: 883000; Reward: -0.0486
# Training - Time: 884000; Reward: -0.084
# Training - Time: 885000; Reward: -0.0506
# Training - Time: 886000; Reward: -0.026
# Training - Time: 887000; Reward: -0.016
# Training - Time: 888000; Reward: -0.0082
# Training - Time: 889000; Reward: -0.0426
# Training - Time: 890000; Reward: -0.047
# Training - Time: 891000; Reward: 0.0056
# Training - Time: 892000; Reward: -0.0126
# Training - Time: 893000; Reward: 0.0012
# Training - Time: 894000; Reward: 0.003
# Training - Time: 895000; Reward: -0.0396
# Training - Time: 896000; Reward: -0.0536
# Training - Time: 897000; Reward: -0.018
# Training - Time: 898000; Reward: -0.026
# Training - Time: 899000; Reward: 0.009
# Training - Time: 900000; Reward: -0.0224
# Training - Time: 901000; Reward: -0.017
# Training - Time: 902000; Reward: -0.03
# Training - Time: 903000; Reward: -0.0592
# Training - Time: 904000; Reward: -0.0158
# Training - Time: 905000; Reward: -0.0324
# Training - Time: 906000; Reward: -0.022
# Training - Time: 907000; Reward: -0.0026
# Training - Time: 908000; Reward: 0.0008
# Training - Time: 909000; Reward: -0.0072
# Training - Time: 910000; Reward: -0.003
# Training - Time: 911000; Reward: -0.0214
# Training - Time: 912000; Reward: -0.048
# Training - Time: 913000; Reward: -0.053
# Training - Time: 914000; Reward: -0.0276
# Training - Time: 915000; Reward: -0.069
# Training - Time: 916000; Reward: -0.0506
# Training - Time: 917000; Reward: -0.042
# Training - Time: 918000; Reward: -0.033
# Training - Time: 919000; Reward: -0.0274
# Training - Time: 920000; Reward: -0.0313
# Training - Time: 921000; Reward: -0.054
# Training - Time: 922000; Reward: -0.009
# Training - Time: 923000; Reward: 0.0036
# Training - Time: 924000; Reward: 0.0184
# Training - Time: 925000; Reward: -0.0508
# Training - Time: 926000; Reward: -0.026
# Training - Time: 927000; Reward: -0.0268
# Training - Time: 928000; Reward: -0.0356
# Training - Time: 929000; Reward: -0.017
# Training - Time: 930000; Reward: -0.0306
# Training - Time: 931000; Reward: -0.0232
# Training - Time: 932000; Reward: -0.0418
# Training - Time: 933000; Reward: 0.026
# Training - Time: 934000; Reward: -0.034
# Training - Time: 935000; Reward: -0.0356
# Training - Time: 936000; Reward: -0.0176
# Training - Time: 937000; Reward: 0.001
# Training - Time: 938000; Reward: -0.0046
# Training - Time: 939000; Reward: -0.0254
# Training - Time: 940000; Reward: 0.0146
# Training - Time: 941000; Reward: -0.0146
# Training - Time: 942000; Reward: -0.0366
# Training - Time: 943000; Reward: 0.0168
# Training - Time: 944000; Reward: -0.0326
# Training - Time: 945000; Reward: -0.025
# Training - Time: 946000; Reward: -0.0018
# Training - Time: 947000; Reward: 0.017
# Training - Time: 948000; Reward: -0.083
# Training - Time: 949000; Reward: -0.009
# Training - Time: 950000; Reward: -0.0086
# Training - Time: 951000; Reward: -0.0186
# Training - Time: 952000; Reward: -0.023
# Training - Time: 953000; Reward: -0.0214
# Training - Time: 954000; Reward: -0.0118
# Training - Time: 955000; Reward: 0.0096
# Training - Time: 956000; Reward: -0.0008
# Training - Time: 957000; Reward: -0.0634
# Training - Time: 958000; Reward: 0.0142
# Training - Time: 959000; Reward: 0.0226
# Training - Time: 960000; Reward: -0.0176
# Training - Time: 961000; Reward: -0.0062
# Training - Time: 962000; Reward: -0.0244
# Training - Time: 963000; Reward: 0.0188
# Training - Time: 964000; Reward: -0.0204
# Training - Time: 965000; Reward: -0.0686
# Training - Time: 966000; Reward: -0.0304
# Training - Time: 967000; Reward: -0.0164
# Training - Time: 968000; Reward: -0.0234
# Training - Time: 969000; Reward: 0.0052
# Training - Time: 970000; Reward: 0.003
# Training - Time: 971000; Reward: -0.0378
# Training - Time: 972000; Reward: -0.0364
# Training - Time: 973000; Reward: -0.019
# Training - Time: 974000; Reward: -0.0338
# Training - Time: 975000; Reward: -0.0276
# Training - Time: 976000; Reward: -0.0014
# Training - Time: 977000; Reward: -0.0008
# Training - Time: 978000; Reward: -0.0184
# Training - Time: 979000; Reward: -0.0068
# Training - Time: 980000; Reward: -0.0246
# Training - Time: 981000; Reward: -0.0104
# Training - Time: 982000; Reward: 0.0052
# Training - Time: 983000; Reward: -0.03
# Training - Time: 984000; Reward: -0.0144
# Training - Time: 985000; Reward: 0.0144
# Training - Time: 986000; Reward: -0.0236
# Training - Time: 987000; Reward: -0.0304
# Training - Time: 988000; Reward: -0.0108
# Training - Time: 989000; Reward: -0.042
# Training - Time: 990000; Reward: -0.004
# Training - Time: 991000; Reward: -0.015
# Training - Time: 992000; Reward: -0.0054
# Training - Time: 993000; Reward: -0.0184
# Training - Time: 994000; Reward: -0.0074
# Training - Time: 995000; Reward: -0.0186
# Training - Time: 996000; Reward: 0.0056
# Training - Time: 997000; Reward: -0.041
# Training - Time: 998000; Reward: 0.0134
# Training - Time: 999000; Reward: -0.066
# Training - Time: 1000000; Reward: -0.0202

# %%
# plot performance
import matplotlib.pyplot as plt
plt.plot(range(3000,1000001,1000),reward_hist2)
plt.title("Rewards of Advanced Model (new network)")
plt.show()
