# %%
import os
os.environ['SDL_VIDEODRIVER']='dummy'
import random
from collections import deque
from pong_player import PongPlayer
import tensorflow as tf
import numpy as np
import cv2
from pygame.constants import K_DOWN, K_UP, K_RIGHT


class DeepQPongPlayer(PongPlayer):
    num_actions = 3  # number of valid actions. In this case up, still and down
    discount_rate = 0.99  # decay rate of past observations
    obs_steps = 100000.  # time steps to observe before training
    exp_steps = 600000.  # frames over which to anneal epsilon
    alpha_init = 1.0  # starting chance of an action being random
    alpha_final = 0.05  # final chance of an action being random
    buffer_size = 120000  # number of observations to remember
    mini_batch = 32  # size of mini batches
    num_frames = 4  # number of frames to store in the state
    resized_image_x, resized_image_y = (80, 80)
    last_ind, action_ind, reward_ind, current_ind, final_ind = range(5)
    record_interval = 49999
    learning_rate = 1e-6
    record_scores_len = 200.

    def __init__(self, checkpoint_path="deep_q_pong_networks_5", playback_mode=False, verbose_logging=False):
        """
        Example of deep q network for pong

        :param checkpoint_path: directory to store checkpoints in
        :type checkpoint_path: str
        :param playback_mode: if true games runs in real time mode and demos itself running
        :type playback_mode: bool
        :param verbose_logging: If true then extra log information is printed to std out
        :type verbose_logging: bool
        """
        self.reward_history = deque()
        self.reward_memory = 0
        
        self._playback_mode = playback_mode
        super(DeepQPongPlayer, self).__init__(force_game_fps=8, run_real_time=playback_mode)
        self.verbose_logging = verbose_logging
        self._checkpoint_path = checkpoint_path
        with tf.device('/gpu:0'):

            self._session = tf.Session()
            self._input_layer, self._output_layer = DeepQPongPlayer._create_network()

            self._action = tf.placeholder("float", [None, self.num_actions])
            self._target = tf.placeholder("float", [None])

            readout_action = tf.reduce_sum(tf.multiply(self._output_layer, self._action), reduction_indices=1)

            cost = tf.reduce_mean(tf.square(self._target - readout_action))
            self._train_operation = tf.train.RMSPropOptimizer(self.learning_rate).minimize(cost)

        self._observations = deque()
        self._last_scores = deque()

        # set the first action to do nothing
        self._last_action = np.zeros(self.num_actions)
        self._last_action[1] = 1

        self._last_state = None
        self._probability_of_random_action = self.alpha_init
        self._time = 0

        self._session.run(tf.global_variables_initializer())

        if not os.path.exists(self._checkpoint_path):
            os.mkdir(self._checkpoint_path)
        
        self._saver = tf.train.Saver()
        checkpoint = tf.train.get_checkpoint_state(self._checkpoint_path)

        if checkpoint and checkpoint.model_checkpoint_path:
            self._saver.restore(self._session, checkpoint.model_checkpoint_path)
            print("Loaded checkpoints %s" % checkpoint.model_checkpoint_path)
        elif playback_mode:
            raise Exception("Could not load checkpoints for playback")

    def get_keys_pressed(self, screen_array, reward, terminal):
        # scale down screen image
        screen_resized_grayscaled = cv2.cvtColor(cv2.resize(screen_array,
                                                            (self.resized_image_x, self.resized_image_y)),
                                                 cv2.COLOR_BGR2GRAY)

        # set the pixels to all be 0. or 1.
        _, screen_resized_binary = cv2.threshold(screen_resized_grayscaled, 1, 255, cv2.THRESH_BINARY)

        if reward != 0.0:
            self._last_scores.append(reward)
            if len(self._last_scores) > self.record_scores_len:
                self._last_scores.popleft()

        # first frame must be handled differently
        if self._last_state is None:
            # the _last_state will contain the image data from the last self.num_frames frames
            self._last_state = np.stack(tuple(screen_resized_binary for _ in range(self.num_frames)), axis=2)

            return DeepQPongPlayer._key_presses_from_action(self._last_action)

        screen_resized_binary = np.reshape(screen_resized_binary,
                                               (self.resized_image_x, self.resized_image_y, 1)) ## 图像处理结束
        
        current_state = np.append(self._last_state[:, :, 1:], screen_resized_binary, axis=2)

        if not self._playback_mode:
            # store the transition in previous_observations
            self._observations.append((self._last_state, self._last_action, reward, current_state, terminal))

            if len(self._observations) > self.buffer_size:
                self._observations.popleft()

            # only train if done observing
            if len(self._observations) > self.obs_steps:
                self._train()
                self._time += 1
            elif ((len(self._observations)+1) % 1000 == 0):
                print('Observation -', len(self._observations)+1,'/',int(self.obs_steps))

        # update the old values
        self._last_state = current_state

        self._last_action = self._choose_next_action()

        if not self._playback_mode:
            # gradually reduce the probability of a random actionself.
            if self._probability_of_random_action > self.alpha_final \
                    and len(self._observations) > self.obs_steps:
                self._probability_of_random_action -= \
                    (self.alpha_init - self.alpha_final) / self.exp_steps
            """
            print("Time: %s random_action_prob: %s reward %s scores differential %s" %
                  (self._time, self._probability_of_random_action, reward,
                   sum(self._last_scores) / self.record_scores_len))
            """
            self.reward_memory += reward
            if (self._time > 1000 and self._time % 1000 == 0):
                self.reward_history.append(self.reward_memory / 1000)
                self.reward_memory = 0
                print("Training - Time: %s; Reward: %s" % (self._time, round(self.reward_history[-1],4)))
            if (self._time >= self.exp_steps-1):
                return [K_RIGHT]    
        return DeepQPongPlayer._key_presses_from_action(self._last_action)

    def _choose_next_action(self):
        new_action = np.zeros([self.num_actions])

        if (not self._playback_mode) and (random.random() <= self._probability_of_random_action):
            # choose an action randomly
            action_index = random.randrange(self.num_actions)
        else:
            # choose an action given our last state
            readout_t = self._session.run(self._output_layer, feed_dict={self._input_layer: [self._last_state]})[0]
            if self.verbose_logging:
                print("Action Q-Values are %s" % readout_t)
            action_index = np.argmax(readout_t)

        new_action[action_index] = 1
        return new_action # 

    def _train(self):
        # sample a mini_batch to train on
        mini_batch = random.sample(self._observations, self.mini_batch)
        # get the batch variables
        previous_states = [d[self.last_ind] for d in mini_batch]
        actions = [d[self.action_ind] for d in mini_batch]
        rewards = [d[self.reward_ind] for d in mini_batch]
        current_states = [d[self.current_ind] for d in mini_batch]
        agents_expected_reward = []
        # this gives us the agents expected reward for each action we might
        agents_reward_per_action = self._session.run(self._output_layer, feed_dict={self._input_layer: current_states})
        for i in range(len(mini_batch)):
            if mini_batch[i][self.final_ind]:
                # this was a terminal frame so there is no future reward...
                agents_expected_reward.append(rewards[i])
            else:
                agents_expected_reward.append(
                    rewards[i] + self.discount_rate * np.max(agents_reward_per_action[i]))

        # learn that these actions in these states lead to this reward
        self._session.run(self._train_operation, feed_dict={
            self._input_layer: previous_states,
            self._action: actions,
            self._target: agents_expected_reward})

        # save checkpoints for later
        if self._time % self.record_interval == 0:
            self._saver.save(self._session, self._checkpoint_path + '/network', global_step=self._time)

    def _create_network():
        # network weights
        with tf.device('/gpu:0'):

        #if 1:
            input_layer = tf.placeholder("float", [None, DeepQPongPlayer.resized_image_x, DeepQPongPlayer.resized_image_y,
                                               DeepQPongPlayer.num_frames])   # Input layer
            
            
            w_1 = tf.Variable(tf.truncated_normal([8, 8, DeepQPongPlayer.num_frames, 16], stddev=0.01))
            b_1 = tf.Variable(tf.constant(0.01, shape=[16]))
            layer_conv1 = tf.nn.relu(tf.nn.conv2d(input_layer, w_1, strides=[1, 4, 4, 1], padding="SAME") + b_1,
                                name= 'Conv1')
            #FIRST HIDDEN LAYER: CONV LAYER, SHAPE =(?, 20, 20, 16)
            # Note:
            # The paper of Deep Mind didn't specify a specific form of recifier nonlinearity. Here we use ReLU, 
            # which is often useful in computer vision topics. 
             
            w_2 = tf.Variable(tf.truncated_normal([4, 4, 16, 32], stddev=0.01))
            b_2 = tf.Variable(tf.constant(0.01, shape=[32]))            
            layer_conv2 = tf.nn.relu(tf.nn.conv2d(layer_conv1, w_2, strides=[1, 2, 2, 1], padding="SAME") + b_2,
                                name = 'Conv2')            
            # SECOND HIDDEN LAYER: CONV LAYER, SHAPE =(?, 10, 10, 32)
            
            layer_2_flat = tf.reshape(layer_conv2, [-1, 10 * 10 * 32])
            layer_dense = tf.layers.dense(inputs=layer_2_flat, units=256,  activation=tf.nn.relu) 
            # THIRD HIDDEN LAYER: FULLY-CONNECTED(DENSE) LAYER, SHAPE = (?, 256)
            
            dropout = tf.layers.dropout(layer_dense, rate=0.2, name = 'Dropout_layer')
            # REGULARIZATION LAYER: TO AVOID OVERFITTING, SHAPE = (?, 256)
            
            output_layer = tf.layers.dense(inputs=dropout, units=3) 
            # OUTPUT LAYER

        return input_layer, output_layer 

    def _key_presses_from_action(action_set):
        if action_set[0] == 1:
            return [K_DOWN]
        elif action_set[1] == 1:
            return []
        elif action_set[2] == 1:
            return [K_UP]
        raise Exception("Unexpected action") 



player = DeepQPongPlayer(checkpoint_path="advanced_model_1")
player.start()
# Out:
# Observation - 1000 / 100000
# Observation - 2000 / 100000
# Observation - 3000 / 100000
# Observation - 4000 / 100000
# Observation - 5000 / 100000
# Observation - 6000 / 100000
# Observation - 7000 / 100000
# Observation - 8000 / 100000
# Observation - 9000 / 100000
# Observation - 10000 / 100000
# Observation - 11000 / 100000
# Observation - 12000 / 100000
# Observation - 13000 / 100000
# Observation - 14000 / 100000
# Observation - 15000 / 100000
# Observation - 16000 / 100000
# Observation - 17000 / 100000
# Observation - 18000 / 100000
# Observation - 19000 / 100000
# Observation - 20000 / 100000
# Observation - 21000 / 100000
# Observation - 22000 / 100000
# Observation - 23000 / 100000
# Observation - 24000 / 100000
# Observation - 25000 / 100000
# Observation - 26000 / 100000
# Observation - 27000 / 100000
# Observation - 28000 / 100000
# Observation - 29000 / 100000
# Observation - 30000 / 100000
# Observation - 31000 / 100000
# Observation - 32000 / 100000
# Observation - 33000 / 100000
# Observation - 34000 / 100000
# Observation - 35000 / 100000
# Observation - 36000 / 100000
# Observation - 37000 / 100000
# Observation - 38000 / 100000
# Observation - 39000 / 100000
# Observation - 40000 / 100000
# Observation - 41000 / 100000
# Observation - 42000 / 100000
# Observation - 43000 / 100000
# Observation - 44000 / 100000
# Observation - 45000 / 100000
# Observation - 46000 / 100000
# Observation - 47000 / 100000
# Observation - 48000 / 100000
# Observation - 49000 / 100000
# Observation - 50000 / 100000
# Observation - 51000 / 100000
# Observation - 52000 / 100000
# Observation - 53000 / 100000
# Observation - 54000 / 100000
# Observation - 55000 / 100000
# Observation - 56000 / 100000
# Observation - 57000 / 100000
# Observation - 58000 / 100000
# Observation - 59000 / 100000
# Observation - 60000 / 100000
# Observation - 61000 / 100000
# Observation - 62000 / 100000
# Observation - 63000 / 100000
# Observation - 64000 / 100000
# Observation - 65000 / 100000
# Observation - 66000 / 100000
# Observation - 67000 / 100000
# Observation - 68000 / 100000
# Observation - 69000 / 100000
# Observation - 70000 / 100000
# Observation - 71000 / 100000
# Observation - 72000 / 100000
# Observation - 73000 / 100000
# Observation - 74000 / 100000
# Observation - 75000 / 100000
# Observation - 76000 / 100000
# Observation - 77000 / 100000
# Observation - 78000 / 100000
# Observation - 79000 / 100000
# Observation - 80000 / 100000
# Observation - 81000 / 100000
# Observation - 82000 / 100000
# Observation - 83000 / 100000
# Observation - 84000 / 100000
# Observation - 85000 / 100000
# Observation - 86000 / 100000
# Observation - 87000 / 100000
# Observation - 88000 / 100000
# Observation - 89000 / 100000
# Observation - 90000 / 100000
# Observation - 91000 / 100000
# Observation - 92000 / 100000
# Observation - 93000 / 100000
# Observation - 94000 / 100000
# Observation - 95000 / 100000
# Observation - 96000 / 100000
# Observation - 97000 / 100000
# Observation - 98000 / 100000
# Observation - 99000 / 100000
# Observation - 100000 / 100000
# Training - Time: 2000; Reward: -5.064
# Training - Time: 3000; Reward: -0.078
# Training - Time: 4000; Reward: -0.056
# Training - Time: 5000; Reward: -0.034
# Training - Time: 6000; Reward: -0.071
# Training - Time: 7000; Reward: -0.066
# Training - Time: 8000; Reward: -0.062
# Training - Time: 9000; Reward: -0.055
# Training - Time: 10000; Reward: -0.056
# Training - Time: 11000; Reward: -0.05
# Training - Time: 12000; Reward: -0.041
# Training - Time: 13000; Reward: -0.072
# Training - Time: 14000; Reward: -0.043
# Training - Time: 15000; Reward: -0.059
# Training - Time: 16000; Reward: -0.067
# Training - Time: 17000; Reward: -0.055
# Training - Time: 18000; Reward: -0.05
# Training - Time: 19000; Reward: -0.038
# Training - Time: 20000; Reward: -0.061
# Training - Time: 21000; Reward: -0.061
# Training - Time: 22000; Reward: -0.041
# Training - Time: 23000; Reward: -0.048
# Training - Time: 24000; Reward: -0.057
# Training - Time: 25000; Reward: -0.037
# Training - Time: 26000; Reward: -0.039
# Training - Time: 27000; Reward: -0.035
# Training - Time: 28000; Reward: -0.063
# Training - Time: 29000; Reward: -0.062
# Training - Time: 30000; Reward: -0.056
# Training - Time: 31000; Reward: -0.044
# Training - Time: 32000; Reward: -0.045
# Training - Time: 33000; Reward: -0.05
# Training - Time: 34000; Reward: -0.06
# Training - Time: 35000; Reward: -0.049
# Training - Time: 36000; Reward: -0.067
# Training - Time: 37000; Reward: -0.04
# Training - Time: 38000; Reward: -0.044
# Training - Time: 39000; Reward: -0.034
# Training - Time: 40000; Reward: -0.039
# Training - Time: 41000; Reward: -0.04
# Training - Time: 42000; Reward: -0.051
# Training - Time: 43000; Reward: -0.051
# Training - Time: 44000; Reward: -0.048
# Training - Time: 45000; Reward: -0.054
# Training - Time: 46000; Reward: -0.046
# Training - Time: 47000; Reward: -0.04
# Training - Time: 48000; Reward: -0.051
# Training - Time: 49000; Reward: -0.049
# Training - Time: 50000; Reward: -0.04
# Training - Time: 51000; Reward: -0.033
# Training - Time: 52000; Reward: -0.048
# Training - Time: 53000; Reward: -0.035
# Training - Time: 54000; Reward: -0.055
# Training - Time: 55000; Reward: -0.05
# Training - Time: 56000; Reward: -0.05
# Training - Time: 57000; Reward: -0.058
# Training - Time: 58000; Reward: -0.048
# Training - Time: 59000; Reward: -0.049
# Training - Time: 60000; Reward: -0.051
# Training - Time: 61000; Reward: -0.053
# Training - Time: 62000; Reward: -0.034
# Training - Time: 63000; Reward: -0.066
# Training - Time: 64000; Reward: -0.052
# Training - Time: 65000; Reward: -0.067
# Training - Time: 66000; Reward: -0.063
# Training - Time: 67000; Reward: -0.058
# Training - Time: 68000; Reward: -0.058
# Training - Time: 69000; Reward: -0.035
# Training - Time: 70000; Reward: -0.037
# Training - Time: 71000; Reward: -0.066
# Training - Time: 72000; Reward: -0.047
# Training - Time: 73000; Reward: -0.051
# Training - Time: 74000; Reward: -0.031
# Training - Time: 75000; Reward: -0.036
# Training - Time: 76000; Reward: -0.058
# Training - Time: 77000; Reward: -0.041
# Training - Time: 78000; Reward: -0.042
# Training - Time: 79000; Reward: -0.059
# Training - Time: 80000; Reward: -0.064
# Training - Time: 81000; Reward: -0.044
# Training - Time: 82000; Reward: -0.038
# Training - Time: 83000; Reward: -0.057
# Training - Time: 84000; Reward: -0.053
# Training - Time: 85000; Reward: -0.043
# Training - Time: 86000; Reward: -0.058
# Training - Time: 87000; Reward: -0.035
# Training - Time: 88000; Reward: -0.056
# Training - Time: 89000; Reward: -0.055
# Training - Time: 90000; Reward: -0.051
# Training - Time: 91000; Reward: -0.039
# Training - Time: 92000; Reward: -0.056
# Training - Time: 93000; Reward: -0.053
# Training - Time: 94000; Reward: -0.062
# Training - Time: 95000; Reward: -0.06
# Training - Time: 96000; Reward: -0.059
# Training - Time: 97000; Reward: -0.056
# Training - Time: 98000; Reward: -0.043
# Training - Time: 99000; Reward: -0.054
# Training - Time: 100000; Reward: -0.047
# Training - Time: 101000; Reward: -0.057
# Training - Time: 102000; Reward: -0.044
# Training - Time: 103000; Reward: -0.05
# Training - Time: 104000; Reward: -0.05
# Training - Time: 105000; Reward: -0.035
# Training - Time: 106000; Reward: -0.053
# Training - Time: 107000; Reward: -0.041
# Training - Time: 108000; Reward: -0.041
# Training - Time: 109000; Reward: -0.077
# Training - Time: 110000; Reward: -0.046
# Training - Time: 111000; Reward: -0.044
# Training - Time: 112000; Reward: -0.036
# Training - Time: 113000; Reward: -0.045
# Training - Time: 114000; Reward: -0.038
# Training - Time: 115000; Reward: -0.048
# Training - Time: 116000; Reward: -0.037
# Training - Time: 117000; Reward: -0.047
# Training - Time: 118000; Reward: -0.063
# Training - Time: 119000; Reward: -0.046
# Training - Time: 120000; Reward: -0.053
# Training - Time: 121000; Reward: -0.043
# Training - Time: 122000; Reward: -0.049
# Training - Time: 123000; Reward: -0.058
# Training - Time: 124000; Reward: -0.066
# Training - Time: 125000; Reward: -0.056
# Training - Time: 126000; Reward: -0.057
# Training - Time: 127000; Reward: -0.05
# Training - Time: 128000; Reward: -0.062
# Training - Time: 129000; Reward: -0.041
# Training - Time: 130000; Reward: -0.031
# Training - Time: 131000; Reward: -0.049
# Training - Time: 132000; Reward: -0.082
# Training - Time: 133000; Reward: -0.038
# Training - Time: 134000; Reward: -0.067
# Training - Time: 135000; Reward: -0.049
# Training - Time: 136000; Reward: -0.056
# Training - Time: 137000; Reward: -0.05
# Training - Time: 138000; Reward: -0.045
# Training - Time: 139000; Reward: -0.043
# Training - Time: 140000; Reward: -0.048
# Training - Time: 141000; Reward: -0.033
# Training - Time: 142000; Reward: -0.052
# Training - Time: 143000; Reward: -0.018
# Training - Time: 144000; Reward: -0.07
# Training - Time: 145000; Reward: -0.055
# Training - Time: 146000; Reward: -0.039
# Training - Time: 147000; Reward: -0.07
# Training - Time: 148000; Reward: -0.048
# Training - Time: 149000; Reward: -0.047
# Training - Time: 150000; Reward: -0.052
# Training - Time: 151000; Reward: -0.047
# Training - Time: 152000; Reward: -0.053
# Training - Time: 153000; Reward: -0.062
# Training - Time: 154000; Reward: -0.054
# Training - Time: 155000; Reward: -0.064
# Training - Time: 156000; Reward: -0.039
# Training - Time: 157000; Reward: -0.052
# Training - Time: 158000; Reward: -0.051
# Training - Time: 159000; Reward: -0.064
# Training - Time: 160000; Reward: -0.047
# Training - Time: 161000; Reward: -0.045
# Training - Time: 162000; Reward: -0.059
# Training - Time: 163000; Reward: -0.064
# Training - Time: 164000; Reward: -0.075
# Training - Time: 165000; Reward: -0.045
# Training - Time: 166000; Reward: -0.06
# Training - Time: 167000; Reward: -0.046
# Training - Time: 168000; Reward: -0.053
# Training - Time: 169000; Reward: -0.059
# Training - Time: 170000; Reward: -0.045
# Training - Time: 171000; Reward: -0.039
# Training - Time: 172000; Reward: -0.049
# Training - Time: 173000; Reward: -0.065
# Training - Time: 174000; Reward: -0.038
# Training - Time: 175000; Reward: -0.04
# Training - Time: 176000; Reward: -0.069
# Training - Time: 177000; Reward: -0.049
# Training - Time: 178000; Reward: -0.041
# Training - Time: 179000; Reward: -0.042
# Training - Time: 180000; Reward: -0.057
# Training - Time: 181000; Reward: -0.051
# Training - Time: 182000; Reward: -0.05
# Training - Time: 183000; Reward: -0.049
# Training - Time: 184000; Reward: -0.053
# Training - Time: 185000; Reward: -0.055
# Training - Time: 186000; Reward: -0.051
# Training - Time: 187000; Reward: -0.038
# Training - Time: 188000; Reward: -0.056
# Training - Time: 189000; Reward: -0.064
# Training - Time: 190000; Reward: -0.069
# Training - Time: 191000; Reward: -0.06
# Training - Time: 192000; Reward: -0.064
# Training - Time: 193000; Reward: -0.043
# Training - Time: 194000; Reward: -0.058
# Training - Time: 195000; Reward: -0.048
# Training - Time: 196000; Reward: -0.065
# Training - Time: 197000; Reward: -0.055
# Training - Time: 198000; Reward: -0.045
# Training - Time: 199000; Reward: -0.068
# Training - Time: 200000; Reward: -0.069
# Training - Time: 201000; Reward: -0.054
# Training - Time: 202000; Reward: -0.058
# Training - Time: 203000; Reward: -0.061
# Training - Time: 204000; Reward: -0.05
# Training - Time: 205000; Reward: -0.038
# Training - Time: 206000; Reward: -0.052
# Training - Time: 207000; Reward: -0.044
# Training - Time: 208000; Reward: -0.039
# Training - Time: 209000; Reward: -0.04
# Training - Time: 210000; Reward: -0.053
# Training - Time: 211000; Reward: -0.04
# Training - Time: 212000; Reward: -0.029
# Training - Time: 213000; Reward: -0.06
# Training - Time: 214000; Reward: -0.044
# Training - Time: 215000; Reward: -0.042
# Training - Time: 216000; Reward: -0.055
# Training - Time: 217000; Reward: -0.043
# Training - Time: 218000; Reward: -0.047
# Training - Time: 219000; Reward: -0.04
# Training - Time: 220000; Reward: -0.063
# Training - Time: 221000; Reward: -0.039
# Training - Time: 222000; Reward: -0.056
# Training - Time: 223000; Reward: -0.05
# Training - Time: 224000; Reward: -0.064
# Training - Time: 225000; Reward: -0.036
# Training - Time: 226000; Reward: -0.043
# Training - Time: 227000; Reward: -0.03
# Training - Time: 228000; Reward: -0.059
# Training - Time: 229000; Reward: -0.05
# Training - Time: 230000; Reward: -0.032
# Training - Time: 231000; Reward: -0.056
# Training - Time: 232000; Reward: -0.048
# Training - Time: 233000; Reward: -0.05
# Training - Time: 234000; Reward: -0.04
# Training - Time: 235000; Reward: -0.036
# Training - Time: 236000; Reward: -0.06
# Training - Time: 237000; Reward: -0.038
# Training - Time: 238000; Reward: -0.044
# Training - Time: 239000; Reward: -0.038
# Training - Time: 240000; Reward: -0.045
# Training - Time: 241000; Reward: -0.047
# Training - Time: 242000; Reward: -0.037
# Training - Time: 243000; Reward: -0.043
# Training - Time: 244000; Reward: -0.037
# Training - Time: 245000; Reward: -0.062
# Training - Time: 246000; Reward: -0.06
# Training - Time: 247000; Reward: -0.04
# Training - Time: 248000; Reward: -0.034
# Training - Time: 249000; Reward: -0.038
# Training - Time: 250000; Reward: -0.048
# Training - Time: 251000; Reward: -0.059
# Training - Time: 252000; Reward: -0.044
# Training - Time: 253000; Reward: -0.059
# Training - Time: 254000; Reward: -0.035
# Training - Time: 255000; Reward: -0.055
# Training - Time: 256000; Reward: -0.043
# Training - Time: 257000; Reward: -0.04
# Training - Time: 258000; Reward: -0.05
# Training - Time: 259000; Reward: -0.06
# Training - Time: 260000; Reward: -0.055
# Training - Time: 261000; Reward: -0.057
# Training - Time: 262000; Reward: -0.038
# Training - Time: 263000; Reward: -0.061
# Training - Time: 264000; Reward: -0.019
# Training - Time: 265000; Reward: -0.046
# Training - Time: 266000; Reward: -0.054
# Training - Time: 267000; Reward: -0.063
# Training - Time: 268000; Reward: -0.042
# Training - Time: 269000; Reward: -0.031
# Training - Time: 270000; Reward: -0.045
# Training - Time: 271000; Reward: -0.063
# Training - Time: 272000; Reward: -0.034
# Training - Time: 273000; Reward: -0.054
# Training - Time: 274000; Reward: -0.052
# Training - Time: 275000; Reward: -0.044
# Training - Time: 276000; Reward: -0.044
# Training - Time: 277000; Reward: -0.046
# Training - Time: 278000; Reward: -0.061
# Training - Time: 279000; Reward: -0.051
# Training - Time: 280000; Reward: -0.044
# Training - Time: 281000; Reward: -0.025
# Training - Time: 282000; Reward: -0.058
# Training - Time: 283000; Reward: -0.048
# Training - Time: 284000; Reward: -0.042
# Training - Time: 285000; Reward: -0.051
# Training - Time: 286000; Reward: -0.027
# Training - Time: 287000; Reward: -0.05
# Training - Time: 288000; Reward: -0.044
# Training - Time: 289000; Reward: -0.037
# Training - Time: 290000; Reward: -0.04
# Training - Time: 291000; Reward: -0.06
# Training - Time: 292000; Reward: -0.017
# Training - Time: 293000; Reward: -0.024
# Training - Time: 294000; Reward: -0.056
# Training - Time: 295000; Reward: -0.047
# Training - Time: 296000; Reward: -0.057
# Training - Time: 297000; Reward: -0.043
# Training - Time: 298000; Reward: -0.039
# Training - Time: 299000; Reward: -0.017
# Training - Time: 300000; Reward: -0.037
# Training - Time: 301000; Reward: -0.034
# Training - Time: 302000; Reward: -0.043
# Training - Time: 303000; Reward: -0.036
# Training - Time: 304000; Reward: -0.05
# Training - Time: 305000; Reward: -0.018
# Training - Time: 306000; Reward: -0.048
# Training - Time: 307000; Reward: -0.051
# Training - Time: 308000; Reward: -0.044
# Training - Time: 309000; Reward: -0.032
# Training - Time: 310000; Reward: -0.035
# Training - Time: 311000; Reward: -0.055
# Training - Time: 312000; Reward: -0.05
# Training - Time: 313000; Reward: -0.034
# Training - Time: 314000; Reward: -0.029
# Training - Time: 315000; Reward: -0.05
# Training - Time: 316000; Reward: -0.042
# Training - Time: 317000; Reward: -0.052
# Training - Time: 318000; Reward: -0.032
# Training - Time: 319000; Reward: -0.069
# Training - Time: 320000; Reward: -0.026
# Training - Time: 321000; Reward: -0.048
# Training - Time: 322000; Reward: -0.051
# Training - Time: 323000; Reward: -0.026
# Training - Time: 324000; Reward: -0.042
# Training - Time: 325000; Reward: -0.036
# Training - Time: 326000; Reward: -0.044
# Training - Time: 327000; Reward: -0.051
# Training - Time: 328000; Reward: -0.035
# Training - Time: 329000; Reward: -0.037
# Training - Time: 330000; Reward: -0.047
# Training - Time: 331000; Reward: -0.031
# Training - Time: 332000; Reward: -0.06
# Training - Time: 333000; Reward: -0.018
# Training - Time: 334000; Reward: -0.037
# Training - Time: 335000; Reward: -0.046
# Training - Time: 336000; Reward: -0.042
# Training - Time: 337000; Reward: -0.035
# Training - Time: 338000; Reward: -0.031
# Training - Time: 339000; Reward: -0.034
# Training - Time: 340000; Reward: -0.035
# Training - Time: 341000; Reward: -0.039
# Training - Time: 342000; Reward: -0.035
# Training - Time: 343000; Reward: -0.031
# Training - Time: 344000; Reward: -0.033
# Training - Time: 345000; Reward: -0.024
# Training - Time: 346000; Reward: -0.031
# Training - Time: 347000; Reward: -0.055
# Training - Time: 348000; Reward: -0.025
# Training - Time: 349000; Reward: -0.038
# Training - Time: 350000; Reward: -0.035
# Training - Time: 351000; Reward: -0.048
# Training - Time: 352000; Reward: -0.044
# Training - Time: 353000; Reward: -0.051
# Training - Time: 354000; Reward: -0.04
# Training - Time: 355000; Reward: -0.031
# Training - Time: 356000; Reward: -0.044
# Training - Time: 357000; Reward: -0.029
# Training - Time: 358000; Reward: -0.03
# Training - Time: 359000; Reward: -0.047
# Training - Time: 360000; Reward: -0.036
# Training - Time: 361000; Reward: -0.025
# Training - Time: 362000; Reward: -0.039
# Training - Time: 363000; Reward: -0.038
# Training - Time: 364000; Reward: -0.047
# Training - Time: 365000; Reward: -0.045
# Training - Time: 366000; Reward: -0.035
# Training - Time: 367000; Reward: -0.035
# Training - Time: 368000; Reward: -0.023
# Training - Time: 369000; Reward: -0.029
# Training - Time: 370000; Reward: -0.036
# Training - Time: 371000; Reward: -0.041
# Training - Time: 372000; Reward: -0.021
# Training - Time: 373000; Reward: -0.022
# Training - Time: 374000; Reward: -0.02
# Training - Time: 375000; Reward: -0.019
# Training - Time: 376000; Reward: -0.051
# Training - Time: 377000; Reward: -0.029
# Training - Time: 378000; Reward: -0.019
# Training - Time: 379000; Reward: -0.03
# Training - Time: 380000; Reward: -0.028
# Training - Time: 381000; Reward: -0.044
# Training - Time: 382000; Reward: -0.038
# Training - Time: 383000; Reward: -0.025
# Training - Time: 384000; Reward: -0.03
# Training - Time: 385000; Reward: -0.028
# Training - Time: 386000; Reward: -0.029
# Training - Time: 387000; Reward: -0.039
# Training - Time: 388000; Reward: -0.038
# Training - Time: 389000; Reward: -0.045
# Training - Time: 390000; Reward: -0.026
# Training - Time: 391000; Reward: -0.033
# Training - Time: 392000; Reward: -0.023
# Training - Time: 393000; Reward: -0.064
# Training - Time: 394000; Reward: -0.039
# Training - Time: 395000; Reward: -0.02
# Training - Time: 396000; Reward: -0.022
# Training - Time: 397000; Reward: -0.015
# Training - Time: 398000; Reward: -0.03
# Training - Time: 399000; Reward: -0.035
# Training - Time: 400000; Reward: -0.033
# Training - Time: 401000; Reward: -0.035
# Training - Time: 402000; Reward: -0.025
# Training - Time: 403000; Reward: -0.055
# Training - Time: 404000; Reward: -0.014
# Training - Time: 405000; Reward: -0.054
# Training - Time: 406000; Reward: -0.026
# Training - Time: 407000; Reward: -0.014
# Training - Time: 408000; Reward: -0.03
# Training - Time: 409000; Reward: -0.017
# Training - Time: 410000; Reward: -0.036
# Training - Time: 411000; Reward: -0.044
# Training - Time: 412000; Reward: -0.016
# Training - Time: 413000; Reward: -0.033
# Training - Time: 414000; Reward: -0.021
# Training - Time: 415000; Reward: -0.021
# Training - Time: 416000; Reward: -0.045
# Training - Time: 417000; Reward: -0.022
# Training - Time: 418000; Reward: -0.036
# Training - Time: 419000; Reward: -0.045
# Training - Time: 420000; Reward: -0.02
# Training - Time: 421000; Reward: -0.036
# Training - Time: 422000; Reward: -0.022
# Training - Time: 423000; Reward: -0.028
# Training - Time: 424000; Reward: -0.025
# Training - Time: 425000; Reward: -0.035
# Training - Time: 426000; Reward: -0.021
# Training - Time: 427000; Reward: -0.004
# Training - Time: 428000; Reward: -0.033
# Training - Time: 429000; Reward: -0.029
# Training - Time: 430000; Reward: -0.033
# Training - Time: 431000; Reward: -0.029
# Training - Time: 432000; Reward: -0.025
# Training - Time: 433000; Reward: -0.021
# Training - Time: 434000; Reward: -0.035
# Training - Time: 435000; Reward: -0.025
# Training - Time: 436000; Reward: -0.023
# Training - Time: 437000; Reward: -0.02
# Training - Time: 438000; Reward: -0.018
# Training - Time: 439000; Reward: -0.021
# Training - Time: 440000; Reward: -0.036
# Training - Time: 441000; Reward: -0.038
# Training - Time: 442000; Reward: -0.032
# Training - Time: 443000; Reward: -0.031
# Training - Time: 444000; Reward: -0.022
# Training - Time: 445000; Reward: -0.019
# Training - Time: 446000; Reward: -0.014
# Training - Time: 447000; Reward: -0.047
# Training - Time: 448000; Reward: -0.025
# Training - Time: 449000; Reward: -0.02
# Training - Time: 450000; Reward: -0.029
# Training - Time: 451000; Reward: -0.03
# Training - Time: 452000; Reward: -0.021
# Training - Time: 453000; Reward: -0.017
# Training - Time: 454000; Reward: -0.025
# Training - Time: 455000; Reward: -0.024
# Training - Time: 456000; Reward: -0.018
# Training - Time: 457000; Reward: -0.025
# Training - Time: 458000; Reward: -0.025
# Training - Time: 459000; Reward: -0.01
# Training - Time: 460000; Reward: -0.034
# Training - Time: 461000; Reward: -0.026
# Training - Time: 462000; Reward: -0.021
# Training - Time: 463000; Reward: -0.034
# Training - Time: 464000; Reward: -0.018
# Training - Time: 465000; Reward: -0.023
# Training - Time: 466000; Reward: -0.025
# Training - Time: 467000; Reward: -0.025
# Training - Time: 468000; Reward: -0.019
# Training - Time: 469000; Reward: -0.017
# Training - Time: 470000; Reward: -0.019
# Training - Time: 471000; Reward: -0.016
# Training - Time: 472000; Reward: -0.03
# Training - Time: 473000; Reward: -0.009
# Training - Time: 474000; Reward: -0.032
# Training - Time: 475000; Reward: -0.038
# Training - Time: 476000; Reward: -0.023
# Training - Time: 477000; Reward: -0.025
# Training - Time: 478000; Reward: -0.011
# Training - Time: 479000; Reward: -0.03
# Training - Time: 480000; Reward: -0.038
# Training - Time: 481000; Reward: -0.02
# Training - Time: 482000; Reward: -0.004
# Training - Time: 483000; Reward: -0.024
# Training - Time: 484000; Reward: -0.027
# Training - Time: 485000; Reward: -0.01
# Training - Time: 486000; Reward: -0.015
# Training - Time: 487000; Reward: -0.028
# Training - Time: 488000; Reward: -0.024
# Training - Time: 489000; Reward: -0.019
# Training - Time: 490000; Reward: -0.017
# Training - Time: 491000; Reward: -0.015
# Training - Time: 492000; Reward: -0.029
# Training - Time: 493000; Reward: -0.02
# Training - Time: 494000; Reward: -0.018
# Training - Time: 495000; Reward: -0.033
# Training - Time: 496000; Reward: -0.027
# Training - Time: 497000; Reward: -0.019
# Training - Time: 498000; Reward: -0.035
# Training - Time: 499000; Reward: -0.023
# Training - Time: 500000; Reward: -0.019
# Training - Time: 501000; Reward: -0.033
# Training - Time: 502000; Reward: -0.022
# Training - Time: 503000; Reward: -0.001
# Training - Time: 504000; Reward: -0.008
# Training - Time: 505000; Reward: -0.02
# Training - Time: 506000; Reward: -0.012
# Training - Time: 507000; Reward: -0.014
# Training - Time: 508000; Reward: -0.025
# Training - Time: 509000; Reward: -0.013
# Training - Time: 510000; Reward: -0.03
# Training - Time: 511000; Reward: -0.034
# Training - Time: 512000; Reward: -0.017
# Training - Time: 513000; Reward: -0.027
# Training - Time: 514000; Reward: -0.038
# Training - Time: 515000; Reward: -0.026
# Training - Time: 516000; Reward: -0.016
# Training - Time: 517000; Reward: -0.021
# Training - Time: 518000; Reward: -0.016
# Training - Time: 519000; Reward: -0.022
# Training - Time: 520000; Reward: -0.017
# Training - Time: 521000; Reward: -0.019
# Training - Time: 522000; Reward: -0.019
# Training - Time: 523000; Reward: -0.012
# Training - Time: 524000; Reward: -0.027
# Training - Time: 525000; Reward: -0.035
# Training - Time: 526000; Reward: -0.01
# Training - Time: 527000; Reward: -0.012
# Training - Time: 528000; Reward: -0.031
# Training - Time: 529000; Reward: -0.033
# Training - Time: 530000; Reward: -0.011
# Training - Time: 531000; Reward: -0.021
# Training - Time: 532000; Reward: -0.019
# Training - Time: 533000; Reward: -0.005
# Training - Time: 534000; Reward: -0.019
# Training - Time: 535000; Reward: -0.021
# Training - Time: 536000; Reward: -0.013
# Training - Time: 537000; Reward: -0.025
# Training - Time: 538000; Reward: -0.022
# Training - Time: 539000; Reward: -0.019
# Training - Time: 540000; Reward: -0.012
# Training - Time: 541000; Reward: -0.021
# Training - Time: 542000; Reward: -0.014
# Training - Time: 543000; Reward: -0.016
# Training - Time: 544000; Reward: -0.015
# Training - Time: 545000; Reward: -0.01
# Training - Time: 546000; Reward: -0.014
# Training - Time: 547000; Reward: -0.013
# Training - Time: 548000; Reward: -0.027
# Training - Time: 549000; Reward: -0.021
# Training - Time: 550000; Reward: -0.014
# Training - Time: 551000; Reward: -0.014
# Training - Time: 552000; Reward: -0.024
# Training - Time: 553000; Reward: -0.004
# Training - Time: 554000; Reward: -0.022
# Training - Time: 555000; Reward: -0.013
# Training - Time: 556000; Reward: -0.016
# Training - Time: 557000; Reward: -0.013
# Training - Time: 558000; Reward: -0.007
# Training - Time: 559000; Reward: -0.022
# Training - Time: 560000; Reward: -0.019
# Training - Time: 561000; Reward: -0.019
# Training - Time: 562000; Reward: -0.011
# Training - Time: 563000; Reward: -0.015
# Training - Time: 564000; Reward: -0.016
# Training - Time: 565000; Reward: -0.026
# Training - Time: 566000; Reward: -0.026
# Training - Time: 567000; Reward: -0.015
# Training - Time: 568000; Reward: -0.018
# Training - Time: 569000; Reward: -0.022
# Training - Time: 570000; Reward: -0.016
# Training - Time: 571000; Reward: -0.004
# Training - Time: 572000; Reward: -0.013
# Training - Time: 573000; Reward: -0.008
# Training - Time: 574000; Reward: -0.005
# Training - Time: 575000; Reward: -0.022
# Training - Time: 576000; Reward: -0.005
# Training - Time: 577000; Reward: -0.008
# Training - Time: 578000; Reward: -0.014
# Training - Time: 579000; Reward: -0.021
# Training - Time: 580000; Reward: -0.018
# Training - Time: 581000; Reward: -0.02
# Training - Time: 582000; Reward: -0.011
# Training - Time: 583000; Reward: -0.007
# Training - Time: 584000; Reward: -0.006
# Training - Time: 585000; Reward: -0.01
# Training - Time: 586000; Reward: -0.01
# Training - Time: 587000; Reward: -0.016
# Training - Time: 588000; Reward: -0.025
# Training - Time: 589000; Reward: -0.012
# Training - Time: 590000; Reward: -0.018
# Training - Time: 591000; Reward: -0.012
# Training - Time: 592000; Reward: -0.026
# Training - Time: 593000; Reward: -0.013
# Training - Time: 594000; Reward: -0.008
# Training - Time: 595000; Reward: -0.015
# Training - Time: 596000; Reward: -0.005
# Training - Time: 597000; Reward: -0.021
# Training - Time: 598000; Reward: -0.009
# Training - Time: 599000; Reward: -0.012
# Training - Time: 600000; Reward: -0.02

# %%
import matplotlib.pyplot as plt
plt.plot(range(3000,600001,1000), reward_hist)
plt.title("Rewards of Model2")
plt.show()
